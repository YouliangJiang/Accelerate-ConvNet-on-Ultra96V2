# %%
import sys
sys.path.append('./data')

import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torch.optim as optim
from matplotlib import pyplot as plt
from dataset import flowerDataset
import torchvision
from torch.autograd import Variable
print("Pytorch Version: ", torch.__version__)
# Out:
# Pytorch Version:  1.7.1

# %% [markdown]
# ### define MobileNetV3 module

# %%
def Hswish(x,inplace=True):
    return x * F.relu6(x + 3., inplace=inplace) / 6.

def Hsigmoid(x,inplace=True):
    return F.relu6(x + 3., inplace=inplace) / 6.

# Squeeze-And-Excite模块
class SEModule(nn.Module):
    def __init__(self, channel, reduction=4):
        super(SEModule, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.se = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y=self.avg_pool(x).view(b, c)
        y=self.se(y)
        y = Hsigmoid(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class Bottleneck(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size,exp_channels,stride,se='True',nl='HS'):
        super(Bottleneck, self).__init__()
        padding = (kernel_size - 1) // 2
        if nl == 'RE':
            self.nlin_layer = F.relu6
        elif nl == 'HS':
            self.nlin_layer = Hswish
        self.stride=stride
        if se:
            self.se=SEModule(exp_channels)
        else:
            self.se=None
        self.conv1=nn.Conv2d(in_channels,exp_channels,kernel_size=1,stride=1,padding=0,bias=False)
        self.bn1 = nn.BatchNorm2d(exp_channels)
        self.conv2=nn.Conv2d(exp_channels,exp_channels,kernel_size=kernel_size,stride=stride,
                             padding=padding,groups=exp_channels,bias=False)
        self.bn2=nn.BatchNorm2d(exp_channels)
        self.conv3=nn.Conv2d(exp_channels,out_channels,kernel_size=1,stride=1,padding=0,bias=False)
        self.bn3=nn.BatchNorm2d(out_channels)
        # 先初始化一个空序列，之后改造其成为残差链接
        self.shortcut = nn.Sequential()
        # 只有步长为1且输入输出通道不相同时才采用跳跃连接(想一下跳跃链接的过程，输入输出通道相同这个跳跃连接就没意义了)
        if stride == 1 and in_channels != out_channels:
            self.shortcut = nn.Sequential(
                # 下面的操作卷积不改变尺寸和通道数
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self,x):
        out=self.nlin_layer(self.bn1(self.conv1(x)))
        if self.se is not None:
            out=self.bn2(self.conv2(out))
            out=self.nlin_layer(self.se(out))
        else:
            out = self.nlin_layer(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = out + self.shortcut(x) if self.stride == 1 else out
        return out


class MobileNetV3_large(nn.Module):
    # (out_channels,kernel_size,exp_channels,stride,se,nl)
    cfg=[
        (16,3,16,1,False,'RE'),
        (24,3,64,2,False,'RE'),
        (24,3,72,1,False,'RE'),
        (40,5,72,2,True,'RE'),
        (40,5,120,1,True,'RE'),
        (40,5,120,1,True,'RE'),
        (80,3,240,2,False,'HS'),
        (80,3,200,1,False,'HS'),
        (80,3,184,1,False,'HS'),
        (80,3,184,1,False,'HS'),
        (112,3,480,1,True,'HS'),
        (112,3,672,1,True,'HS'),
        (160,5,672,2,True,'HS'),
        (160,5,960,1,True,'HS'),
        (160,5,960,1,True,'HS')
    ]
    def __init__(self,num_classes=17):
        super(MobileNetV3_large,self).__init__()
        self.conv1=nn.Conv2d(3,16,3,2,padding=1,bias=False)
        self.bn1=nn.BatchNorm2d(16)
        # 根据cfg数组自动生成所有的Bottleneck层
        self.layers = self._make_layers(in_channels=16)
        self.conv2=nn.Conv2d(160,960,1,stride=1,bias=False)
        self.bn2=nn.BatchNorm2d(960)
        # 卷积后不跟BN，就应该把bias设置为True
        self.conv3=nn.Conv2d(960,1280,1,1,padding=0,bias=True)
        self.conv4=nn.Conv2d(1280,num_classes,1,stride=1,padding=0,bias=True)

    def _make_layers(self,in_channels):
        layers=[]
        for out_channels,kernel_size,exp_channels,stride,se,nl in self.cfg:
            layers.append(
                Bottleneck(in_channels,out_channels,kernel_size,exp_channels,stride,se,nl)
            )
            in_channels=out_channels
        return nn.Sequential(*layers)

    def forward(self,x):
        out=Hswish(self.bn1(self.conv1(x)))
        out=self.layers(out)
        out=Hswish(self.bn2(self.conv2(out)))
        out=F.avg_pool2d(out,7)
        out=Hswish(self.conv3(out))
        out=self.conv4(out)
        # 因为原论文中最后一层是卷积层来实现全连接的效果，维度是四维的，后两维是1，在计算损失函数的时候要求二维，因此在这里需要做一个resize
        a,b=out.size(0),out.size(1)
        out=out.view(a,b)
        return out

class MobileNetV3_small(nn.Module):
    # (out_channels,kernel_size,exp_channels,stride,se,nl)
    cfg = [
        (16,3,16,2,True,'RE'),
        (24,3,72,2,False,'RE'),
        (24,3,88,1,False,'RE'),
        (40,5,96,2,True,'HS'),
        (40,5,240,1,True,'HS'),
        (40,5,240,1,True,'HS'),
        (48,5,120,1,True,'HS'),
        (48,5,144,1,True,'HS'),
        (96,5,288,2,True,'HS'),
        (96,5,576,1,True,'HS'),
        (96,5,576,1,True,'HS')
    ]
    def __init__(self,num_classes=17):
        super(MobileNetV3_small,self).__init__()
        self.conv1=nn.Conv2d(3,16,3,2,padding=1,bias=False)
        self.bn1=nn.BatchNorm2d(16)
        # 根据cfg数组自动生成所有的Bottleneck层
        self.layers = self._make_layers(in_channels=16)
        self.conv2=nn.Conv2d(96,576,1,stride=1,bias=False)
        self.bn2=nn.BatchNorm2d(576)
        # 卷积后不跟BN，就应该把bias设置为True
        self.conv3=nn.Conv2d(576,1280,1,1,padding=0,bias=True)
        self.conv4=nn.Conv2d(1280,num_classes,1,stride=1,padding=0,bias=True)

    def _make_layers(self,in_channels):
        layers=[]
        for out_channels,kernel_size,exp_channels,stride,se,nl in self.cfg:
            layers.append(
                Bottleneck(in_channels,out_channels,kernel_size,exp_channels,stride,se,nl)
            )
            in_channels=out_channels
        return nn.Sequential(*layers)

    def forward(self,x):
        out=Hswish(self.bn1(self.conv1(x)))
        out=self.layers(out)
        out=self.bn2(self.conv2(out))
        se=SEModule(out.size(1))
        out=Hswish(se(out))
        out = F.avg_pool2d(out, 7)
        out = Hswish(self.conv3(out))
        out = self.conv4(out)
        # 因为原论文中最后一层是卷积层来实现全连接的效果，维度是四维的，后两维是1，在计算损失函数的时候要求二维，因此在这里需要做一个resize
        a, b = out.size(0), out.size(1)
        out = out.view(a, b)
        return out


def module_test():
    net=MobileNetV3_small()
    x=torch.randn(2,3,224,224)
    y=net(x)
    print(y.size())
    print(y)
#
# if __name__=="__main__":
#     module_test()

# %% [markdown]
# ### train

# %%
#宏定义一些数据，如epoch数，batchsize等
MAX_EPOCH=50
BATCH_SIZE=12
LR=0.0001
log_interval=3
val_interval=1

# %%
# ============================ step 1/5 数据 ============================
split_dir=os.path.join(".","data","splitData")
train_dir=os.path.join(split_dir,"train")
valid_dir=os.path.join(split_dir,"valid")

#对训练集所需要做的预处理
train_transform=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

#对验证集所需要做的预处理
valid_transform=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

# 构建MyDataset实例
train_data=flowerDataset(data_dir=train_dir,transform=train_transform)
valid_data=flowerDataset(data_dir=valid_dir,transform=valid_transform)

# 构建DataLoader
# 训练集数据最好打乱
# DataLoader的实质就是把数据集加上一个索引号，再返回
train_loader=DataLoader(dataset=train_data,batch_size=BATCH_SIZE,shuffle=True)
valid_loader=DataLoader(dataset=valid_data,batch_size=BATCH_SIZE)

# %%
# ============================ step 2/5 模型 ============================
net=MobileNetV3_small(num_classes=17)
if torch.cuda.is_available():
    net.cuda()

# %%
# ============================ step 3/5 损失函数 ============================
criterion=nn.CrossEntropyLoss()

# %%
# ============================ step 4/5 优化器 ============================
optimizer=optim.Adam(net.parameters(),lr=LR, betas=(0.9, 0.99))# 选择优化器

# %%
# ============================ step 5/5 训练 ============================
# 记录每一次的数据，方便绘图
train_curve=list()
valid_curve=list()
net.train()
accurancy_global=0.0

for epoch in range(MAX_EPOCH):
    loss_mean=0.
    correct=0.
    total=0.
    running_loss = 0.0

    for i,data in enumerate(train_loader):
        img,label=data
        img = Variable(img)
        label = Variable(label)
        if torch.cuda.is_available():
            img=img.cuda()
            label=label.cuda()
            
        # 前向传播
        out=net(img)
        optimizer.zero_grad()  # 归0梯度
        loss=criterion(out,label)#得到损失函数

        print_loss=loss.data.item()

        loss.backward()#反向传播
        optimizer.step()#优化
        if (i+1)%log_interval==0:
            print('epoch:{},loss:{:.4f}'.format(epoch+1,loss.data.item()))
        _, predicted = torch.max(out.data, 1)
        total += label.size(0)

        correct += (predicted == label).sum()
    print("============================================")
    accurancy=correct / total
    if accurancy>accurancy_global:
        torch.save(net, './weights/mobilenetv3_small_best.pkl')
        print("准确率由：", accurancy_global, "上升至：", accurancy, "已更新并保存权值为weights/mobilenetv3_small_best.pkl")
        accurancy_global=accurancy
    print('第%d个epoch的识别准确率为：%d%%' % (epoch + 1, 100*accurancy))

torch.save(net, './weights/mobilenetv3_small_last.pkl')
print("训练完毕，权重已保存为：weights/mobilenetv3_small_last.pkl")
# Out:
# epoch:1,loss:2.8295
# epoch:1,loss:2.8362
# epoch:1,loss:2.8213
# epoch:1,loss:2.8160
# epoch:1,loss:2.8091
# epoch:1,loss:2.7895
# epoch:1,loss:2.7912
# epoch:1,loss:2.8422
# epoch:1,loss:2.7545
# epoch:1,loss:2.8413
# epoch:1,loss:2.7419
# epoch:1,loss:2.8340
# epoch:1,loss:2.7724
# epoch:1,loss:2.7339
# epoch:1,loss:2.6758
# epoch:1,loss:2.7644
# epoch:1,loss:2.8381
# epoch:1,loss:2.6368
# epoch:1,loss:2.7216
# epoch:1,loss:2.7274
# epoch:1,loss:2.7478
# epoch:1,loss:2.7881
# epoch:1,loss:2.3802
# epoch:1,loss:2.7555
# epoch:1,loss:2.5850
# epoch:1,loss:2.6754
# epoch:1,loss:2.3837
# epoch:1,loss:2.7608
# epoch:1,loss:2.5011
# epoch:1,loss:2.8282
# ============================================
# 准确率由： 0.0 上升至： tensor(0.1241) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第1个epoch的识别准确率为：12%
# epoch:2,loss:2.6401
# epoch:2,loss:2.2038
# epoch:2,loss:2.4756
# epoch:2,loss:2.6820
# epoch:2,loss:2.5558
# epoch:2,loss:2.3857
# epoch:2,loss:2.4500
# epoch:2,loss:2.5564
# epoch:2,loss:2.6627
# epoch:2,loss:2.2561
# epoch:2,loss:2.4832
# epoch:2,loss:2.4108
# epoch:2,loss:2.4368
# epoch:2,loss:2.5672
# epoch:2,loss:2.0911
# epoch:2,loss:2.1208
# epoch:2,loss:2.3883
# epoch:2,loss:2.6157
# epoch:2,loss:2.5376
# epoch:2,loss:2.2351
# epoch:2,loss:2.1360
# epoch:2,loss:2.4803
# epoch:2,loss:2.3288
# epoch:2,loss:2.6894
# epoch:2,loss:2.1183
# epoch:2,loss:2.3243
# epoch:2,loss:1.9819
# epoch:2,loss:2.1221
# epoch:2,loss:2.2050
# epoch:2,loss:2.5853
# ============================================
# 准确率由： tensor(0.1241) 上升至： tensor(0.1866) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第2个epoch的识别准确率为：18%
# epoch:3,loss:2.2143
# epoch:3,loss:2.5225
# epoch:3,loss:2.0375
# epoch:3,loss:2.3250
# epoch:3,loss:2.0636
# epoch:3,loss:2.3682
# epoch:3,loss:2.1867
# epoch:3,loss:1.7785
# epoch:3,loss:1.9726
# epoch:3,loss:2.1627
# epoch:3,loss:2.2245
# epoch:3,loss:1.9767
# epoch:3,loss:2.4549
# epoch:3,loss:2.2310
# epoch:3,loss:2.6375
# epoch:3,loss:2.0338
# epoch:3,loss:2.0155
# epoch:3,loss:2.2557
# epoch:3,loss:1.9258
# epoch:3,loss:2.4591
# epoch:3,loss:1.9084
# epoch:3,loss:1.8401
# epoch:3,loss:2.4642
# epoch:3,loss:2.3135
# epoch:3,loss:2.5787
# epoch:3,loss:2.0069
# epoch:3,loss:1.9934
# epoch:3,loss:2.0307
# epoch:3,loss:1.7481
# epoch:3,loss:1.7667
# ============================================
# 准确率由： tensor(0.1866) 上升至： tensor(0.2509) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第3个epoch的识别准确率为：25%
# epoch:4,loss:2.1259
# epoch:4,loss:2.0906
# epoch:4,loss:2.3444
# epoch:4,loss:1.8930
# epoch:4,loss:1.6880
# epoch:4,loss:1.8788
# epoch:4,loss:1.8236
# epoch:4,loss:1.7770
# epoch:4,loss:1.9030
# epoch:4,loss:1.7735
# epoch:4,loss:2.1274
# epoch:4,loss:1.9815
# epoch:4,loss:1.9724
# epoch:4,loss:2.0092
# epoch:4,loss:1.6078
# epoch:4,loss:2.4585
# epoch:4,loss:2.2733
# epoch:4,loss:2.1385
# epoch:4,loss:1.7048
# epoch:4,loss:2.0493
# epoch:4,loss:1.7430
# epoch:4,loss:2.0489
# epoch:4,loss:2.4050
# epoch:4,loss:2.1556
# epoch:4,loss:1.7156
# epoch:4,loss:2.2013
# epoch:4,loss:2.1312
# epoch:4,loss:1.6579
# epoch:4,loss:2.4244
# epoch:4,loss:1.5667
# ============================================
# 准确率由： tensor(0.2509) 上升至： tensor(0.2960) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第4个epoch的识别准确率为：29%
# epoch:5,loss:1.9995
# epoch:5,loss:1.9185
# epoch:5,loss:1.4399
# epoch:5,loss:1.6634
# epoch:5,loss:1.7141
# epoch:5,loss:1.8628
# epoch:5,loss:1.9387
# epoch:5,loss:2.4963
# epoch:5,loss:2.1022
# epoch:5,loss:1.9946
# epoch:5,loss:2.0214
# epoch:5,loss:1.9449
# epoch:5,loss:2.0560
# epoch:5,loss:1.5376
# epoch:5,loss:1.9915
# epoch:5,loss:1.7613
# epoch:5,loss:1.7737
# epoch:5,loss:1.8093
# epoch:5,loss:1.5305
# epoch:5,loss:1.7254
# epoch:5,loss:2.0639
# epoch:5,loss:1.7422
# epoch:5,loss:1.6863
# epoch:5,loss:1.5694
# epoch:5,loss:1.9358
# epoch:5,loss:1.8816
# epoch:5,loss:1.6799
# epoch:5,loss:1.7006
# epoch:5,loss:1.7849
# epoch:5,loss:1.7642
# ============================================
# 准确率由： tensor(0.2960) 上升至： tensor(0.3667) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第5个epoch的识别准确率为：36%
# epoch:6,loss:1.4673
# epoch:6,loss:1.6219
# epoch:6,loss:1.7325
# epoch:6,loss:1.6199
# epoch:6,loss:1.6502
# epoch:6,loss:1.6292
# epoch:6,loss:2.2565
# epoch:6,loss:1.5804
# epoch:6,loss:1.9157
# epoch:6,loss:2.0457
# epoch:6,loss:1.8719
# epoch:6,loss:2.1101
# epoch:6,loss:1.6449
# epoch:6,loss:2.0609
# epoch:6,loss:2.8695
# epoch:6,loss:1.6954
# epoch:6,loss:1.7169
# epoch:6,loss:1.6517
# epoch:6,loss:1.4253
# epoch:6,loss:1.8241
# epoch:6,loss:2.2281
# epoch:6,loss:1.5657
# epoch:6,loss:2.2788
# epoch:6,loss:1.7399
# epoch:6,loss:1.5103
# epoch:6,loss:2.0596
# epoch:6,loss:1.5298
# epoch:6,loss:1.3585
# epoch:6,loss:1.4901
# epoch:6,loss:1.6372
# ============================================
# 准确率由： tensor(0.3667) 上升至： tensor(0.3778) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第6个epoch的识别准确率为：37%
# epoch:7,loss:1.4895
# epoch:7,loss:1.4241
# epoch:7,loss:1.5144
# epoch:7,loss:1.5995
# epoch:7,loss:1.1145
# epoch:7,loss:1.7605
# epoch:7,loss:1.7059
# epoch:7,loss:1.4019
# epoch:7,loss:1.8397
# epoch:7,loss:1.3499
# epoch:7,loss:1.9587
# epoch:7,loss:1.2015
# epoch:7,loss:1.3926
# epoch:7,loss:1.5170
# epoch:7,loss:1.7413
# epoch:7,loss:1.5975
# epoch:7,loss:1.3282
# epoch:7,loss:1.9205
# epoch:7,loss:1.4569
# epoch:7,loss:1.4735
# epoch:7,loss:1.5970
# epoch:7,loss:1.8776
# epoch:7,loss:1.9388
# epoch:7,loss:1.3645
# epoch:7,loss:2.1147
# epoch:7,loss:1.6496
# epoch:7,loss:1.6266
# epoch:7,loss:1.4759
# epoch:7,loss:1.7407
# epoch:7,loss:1.4427
# ============================================
# 准确率由： tensor(0.3778) 上升至： tensor(0.4393) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第7个epoch的识别准确率为：43%
# epoch:8,loss:1.1469
# epoch:8,loss:1.3869
# epoch:8,loss:1.4335
# epoch:8,loss:1.8015
# epoch:8,loss:1.7302
# epoch:8,loss:1.4366
# epoch:8,loss:1.9825
# epoch:8,loss:1.5977
# epoch:8,loss:1.6568
# epoch:8,loss:1.4416
# epoch:8,loss:2.0171
# epoch:8,loss:1.7471
# epoch:8,loss:1.6289
# epoch:8,loss:2.3169
# epoch:8,loss:1.3322
# epoch:8,loss:1.4094
# epoch:8,loss:1.5474
# epoch:8,loss:1.0265
# epoch:8,loss:1.5047
# epoch:8,loss:1.4636
# epoch:8,loss:1.5411
# epoch:8,loss:1.9402
# epoch:8,loss:1.4731
# epoch:8,loss:1.3906
# epoch:8,loss:1.5471
# epoch:8,loss:1.3297
# epoch:8,loss:1.4358
# epoch:8,loss:0.9411
# epoch:8,loss:0.9790
# epoch:8,loss:1.2647
# ============================================
# 准确率由： tensor(0.4393) 上升至： tensor(0.4669) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第8个epoch的识别准确率为：46%
# epoch:9,loss:1.8510
# epoch:9,loss:1.4338
# epoch:9,loss:1.7496
# epoch:9,loss:1.8136
# epoch:9,loss:1.1726
# epoch:9,loss:1.3541
# epoch:9,loss:1.2622
# epoch:9,loss:1.0983
# epoch:9,loss:1.3560
# epoch:9,loss:1.5968
# epoch:9,loss:1.7880
# epoch:9,loss:1.3989
# epoch:9,loss:2.1246
# epoch:9,loss:1.1702
# epoch:9,loss:1.0387
# epoch:9,loss:1.1825
# epoch:9,loss:1.5714
# epoch:9,loss:1.5621
# epoch:9,loss:1.2488
# epoch:9,loss:1.2548
# epoch:9,loss:1.7318
# epoch:9,loss:1.2562
# epoch:9,loss:1.4416
# epoch:9,loss:1.7221
# epoch:9,loss:0.9891
# epoch:9,loss:1.7192
# epoch:9,loss:1.5464
# epoch:9,loss:1.4365
# epoch:9,loss:1.2621
# epoch:9,loss:1.0514
# ============================================
# 准确率由： tensor(0.4669) 上升至： tensor(0.4862) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第9个epoch的识别准确率为：48%
# epoch:10,loss:0.9697
# epoch:10,loss:1.1277
# epoch:10,loss:1.4479
# epoch:10,loss:1.1998
# epoch:10,loss:1.6006
# epoch:10,loss:1.3179
# epoch:10,loss:1.1534
# epoch:10,loss:1.2101
# epoch:10,loss:1.3500
# epoch:10,loss:1.0964
# epoch:10,loss:1.2606
# epoch:10,loss:1.8347
# epoch:10,loss:1.0865
# epoch:10,loss:1.4476
# epoch:10,loss:2.1397
# epoch:10,loss:1.0500
# epoch:10,loss:0.9430
# epoch:10,loss:1.7027
# epoch:10,loss:1.2088
# epoch:10,loss:1.3372
# epoch:10,loss:1.0690
# epoch:10,loss:1.0153
# epoch:10,loss:1.0662
# epoch:10,loss:1.2200
# epoch:10,loss:1.0386
# epoch:10,loss:1.4794
# epoch:10,loss:1.3284
# epoch:10,loss:1.4713
# epoch:10,loss:1.1360
# epoch:10,loss:1.1490
# ============================================
# 准确率由： tensor(0.4862) 上升至： tensor(0.5542) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第10个epoch的识别准确率为：55%
# epoch:11,loss:1.2758
# epoch:11,loss:2.0219
# epoch:11,loss:1.4566
# epoch:11,loss:1.2886
# epoch:11,loss:0.7405
# epoch:11,loss:1.1887
# epoch:11,loss:1.2123
# epoch:11,loss:1.3578
# epoch:11,loss:1.0605
# epoch:11,loss:0.9282
# epoch:11,loss:0.6331
# epoch:11,loss:0.9176
# epoch:11,loss:1.3933
# epoch:11,loss:0.8756
# epoch:11,loss:1.2526
# epoch:11,loss:1.3562
# epoch:11,loss:1.1679
# epoch:11,loss:1.8008
# epoch:11,loss:0.8665
# epoch:11,loss:0.9262
# epoch:11,loss:1.2682
# epoch:11,loss:1.2556
# epoch:11,loss:1.1328
# epoch:11,loss:1.0091
# epoch:11,loss:1.8311
# epoch:11,loss:1.6052
# epoch:11,loss:1.3293
# epoch:11,loss:0.7244
# epoch:11,loss:1.5417
# epoch:11,loss:1.2934
# ============================================
# 准确率由： tensor(0.5542) 上升至： tensor(0.5790) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第11个epoch的识别准确率为：57%
# epoch:12,loss:1.2528
# epoch:12,loss:0.6257
# epoch:12,loss:1.0929
# epoch:12,loss:1.3599
# epoch:12,loss:1.1220
# epoch:12,loss:0.9403
# epoch:12,loss:1.1208
# epoch:12,loss:0.9956
# epoch:12,loss:0.9270
# epoch:12,loss:1.0419
# epoch:12,loss:0.9568
# epoch:12,loss:1.4081
# epoch:12,loss:1.1171
# epoch:12,loss:0.7972
# epoch:12,loss:1.4273
# epoch:12,loss:0.9166
# epoch:12,loss:1.1608
# epoch:12,loss:0.9616
# epoch:12,loss:1.0161
# epoch:12,loss:0.9740
# epoch:12,loss:1.5452
# epoch:12,loss:1.4900
# epoch:12,loss:0.7721
# epoch:12,loss:1.5859
# epoch:12,loss:0.9792
# epoch:12,loss:1.2377
# epoch:12,loss:0.8858
# epoch:12,loss:1.2491
# epoch:12,loss:0.9087
# epoch:12,loss:1.1556
# ============================================
# 准确率由： tensor(0.5790) 上升至： tensor(0.6176) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第12个epoch的识别准确率为：61%
# epoch:13,loss:1.1013
# epoch:13,loss:0.7452
# epoch:13,loss:1.1491
# epoch:13,loss:0.8293
# epoch:13,loss:1.1031
# epoch:13,loss:1.6964
# epoch:13,loss:0.7906
# epoch:13,loss:1.0826
# epoch:13,loss:0.8106
# epoch:13,loss:0.6242
# epoch:13,loss:1.3030
# epoch:13,loss:0.7219
# epoch:13,loss:1.0873
# epoch:13,loss:0.9390
# epoch:13,loss:1.5692
# epoch:13,loss:1.1112
# epoch:13,loss:1.2226
# epoch:13,loss:0.8097
# epoch:13,loss:0.7234
# epoch:13,loss:1.1220
# epoch:13,loss:0.9534
# epoch:13,loss:1.7293
# epoch:13,loss:0.8452
# epoch:13,loss:0.7711
# epoch:13,loss:1.1238
# epoch:13,loss:1.0831
# epoch:13,loss:0.6906
# epoch:13,loss:1.5236
# epoch:13,loss:0.6623
# epoch:13,loss:1.2127
# ============================================
# 准确率由： tensor(0.6176) 上升至： tensor(0.6461) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第13个epoch的识别准确率为：64%
# epoch:14,loss:1.0695
# epoch:14,loss:0.5025
# epoch:14,loss:0.6071
# epoch:14,loss:1.1619
# epoch:14,loss:0.6944
# epoch:14,loss:0.7074
# epoch:14,loss:0.7922
# epoch:14,loss:0.9500
# epoch:14,loss:1.2567
# epoch:14,loss:1.2291
# epoch:14,loss:0.6844
# epoch:14,loss:0.7732
# epoch:14,loss:0.8880
# epoch:14,loss:1.4442
# epoch:14,loss:0.8459
# epoch:14,loss:0.9132
# epoch:14,loss:0.4950
# epoch:14,loss:0.7869
# epoch:14,loss:0.9953
# epoch:14,loss:1.2451
# epoch:14,loss:1.1490
# epoch:14,loss:0.5580
# epoch:14,loss:1.0615
# epoch:14,loss:0.5722
# epoch:14,loss:1.0709
# epoch:14,loss:0.9858
# epoch:14,loss:0.8710
# epoch:14,loss:1.6735
# epoch:14,loss:0.8401
# epoch:14,loss:1.3258
# ============================================
# 准确率由： tensor(0.6461) 上升至： tensor(0.6811) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第14个epoch的识别准确率为：68%
# epoch:15,loss:0.6776
# epoch:15,loss:1.1190
# epoch:15,loss:1.1326
# epoch:15,loss:1.4759
# epoch:15,loss:0.6778
# epoch:15,loss:0.5838
# epoch:15,loss:0.8138
# epoch:15,loss:1.0277
# epoch:15,loss:0.5902
# epoch:15,loss:0.8419
# epoch:15,loss:0.8590
# epoch:15,loss:0.6585
# epoch:15,loss:0.5685
# epoch:15,loss:1.4391
# epoch:15,loss:1.1380
# epoch:15,loss:0.8780
# epoch:15,loss:0.7851
# epoch:15,loss:0.6766
# epoch:15,loss:1.0950
# epoch:15,loss:1.0519
# epoch:15,loss:0.6092
# epoch:15,loss:0.5445
# epoch:15,loss:1.2680
# epoch:15,loss:1.0734
# epoch:15,loss:1.9893
# epoch:15,loss:0.9427
# epoch:15,loss:0.4414
# epoch:15,loss:0.8577
# epoch:15,loss:0.7103
# epoch:15,loss:0.7134
# ============================================
# 准确率由： tensor(0.6811) 上升至： tensor(0.6857) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第15个epoch的识别准确率为：68%
# epoch:16,loss:0.5078
# epoch:16,loss:0.6792
# epoch:16,loss:1.3035
# epoch:16,loss:0.6277
# epoch:16,loss:0.5704
# epoch:16,loss:0.5539
# epoch:16,loss:1.6646
# epoch:16,loss:0.8497
# epoch:16,loss:0.8309
# epoch:16,loss:0.8183
# epoch:16,loss:0.7783
# epoch:16,loss:0.8783
# epoch:16,loss:0.5665
# epoch:16,loss:0.5147
# epoch:16,loss:0.6303
# epoch:16,loss:0.5617
# epoch:16,loss:0.6293
# epoch:16,loss:0.6922
# epoch:16,loss:0.6258
# epoch:16,loss:0.5699
# epoch:16,loss:1.2745
# epoch:16,loss:0.8742
# epoch:16,loss:0.8924
# epoch:16,loss:1.5771
# epoch:16,loss:0.4824
# epoch:16,loss:0.5652
# epoch:16,loss:0.4767
# epoch:16,loss:1.0107
# epoch:16,loss:0.8796
# epoch:16,loss:0.6443
# ============================================
# 准确率由： tensor(0.6857) 上升至： tensor(0.7472) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第16个epoch的识别准确率为：74%
# epoch:17,loss:0.5296
# epoch:17,loss:0.8761
# epoch:17,loss:0.4537
# epoch:17,loss:0.7027
# epoch:17,loss:0.4922
# epoch:17,loss:0.6851
# epoch:17,loss:0.4680
# epoch:17,loss:0.3845
# epoch:17,loss:0.3896
# epoch:17,loss:0.4855
# epoch:17,loss:0.5539
# epoch:17,loss:0.7904
# epoch:17,loss:0.6939
# epoch:17,loss:0.7684
# epoch:17,loss:0.6316
# epoch:17,loss:0.5568
# epoch:17,loss:0.7964
# epoch:17,loss:0.4727
# epoch:17,loss:0.5471
# epoch:17,loss:0.5144
# epoch:17,loss:0.8606
# epoch:17,loss:0.4033
# epoch:17,loss:0.9811
# epoch:17,loss:0.6718
# epoch:17,loss:0.4393
# epoch:17,loss:1.6141
# epoch:17,loss:0.8924
# epoch:17,loss:1.0663
# epoch:17,loss:1.0281
# epoch:17,loss:0.7077
# ============================================
# 准确率由： tensor(0.7472) 上升至： tensor(0.7574) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第17个epoch的识别准确率为：75%
# epoch:18,loss:0.4339
# epoch:18,loss:0.9824
# epoch:18,loss:0.7207
# epoch:18,loss:0.4311
# epoch:18,loss:0.3542
# epoch:18,loss:0.6994
# epoch:18,loss:0.3469
# epoch:18,loss:0.4008
# epoch:18,loss:0.5996
# epoch:18,loss:0.5441
# epoch:18,loss:0.3509
# epoch:18,loss:0.9614
# epoch:18,loss:0.5023
# epoch:18,loss:0.8481
# epoch:18,loss:1.0561
# epoch:18,loss:0.7872
# epoch:18,loss:0.5345
# epoch:18,loss:0.7164
# epoch:18,loss:0.5567
# epoch:18,loss:0.5466
# epoch:18,loss:0.5333
# epoch:18,loss:0.5351
# epoch:18,loss:0.8097
# epoch:18,loss:0.3102
# epoch:18,loss:0.5530
# epoch:18,loss:0.1980
# epoch:18,loss:0.3898
# epoch:18,loss:0.5086
# epoch:18,loss:0.5920
# epoch:18,loss:0.4476
# ============================================
# 准确率由： tensor(0.7574) 上升至： tensor(0.7868) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第18个epoch的识别准确率为：78%
# epoch:19,loss:1.2324
# epoch:19,loss:1.0120
# epoch:19,loss:0.3548
# epoch:19,loss:0.8905
# epoch:19,loss:1.0451
# epoch:19,loss:0.4577
# epoch:19,loss:0.3842
# epoch:19,loss:0.5886
# epoch:19,loss:0.4663
# epoch:19,loss:0.4208
# epoch:19,loss:0.4215
# epoch:19,loss:1.0952
# epoch:19,loss:0.7509
# epoch:19,loss:1.1862
# epoch:19,loss:0.3276
# epoch:19,loss:0.1835
# epoch:19,loss:0.2968
# epoch:19,loss:0.4182
# epoch:19,loss:1.0206
# epoch:19,loss:0.2030
# epoch:19,loss:0.6364
# epoch:19,loss:0.5244
# epoch:19,loss:0.3088
# epoch:19,loss:0.2590
# epoch:19,loss:0.7590
# epoch:19,loss:0.9922
# epoch:19,loss:0.6973
# epoch:19,loss:0.6106
# epoch:19,loss:0.6082
# epoch:19,loss:0.6457
# ============================================
# 第19个epoch的识别准确率为：77%
# epoch:20,loss:1.1695
# epoch:20,loss:0.3966
# epoch:20,loss:0.5427
# epoch:20,loss:0.2971
# epoch:20,loss:0.3429
# epoch:20,loss:0.3003
# epoch:20,loss:1.4237
# epoch:20,loss:0.2171
# epoch:20,loss:0.7526
# epoch:20,loss:0.4915
# epoch:20,loss:0.5436
# epoch:20,loss:0.3453
# epoch:20,loss:0.3783
# epoch:20,loss:0.7322
# epoch:20,loss:0.4907
# epoch:20,loss:0.2895
# epoch:20,loss:0.6264
# epoch:20,loss:0.5376
# epoch:20,loss:0.2846
# epoch:20,loss:0.2707
# epoch:20,loss:0.3882
# epoch:20,loss:0.6498
# epoch:20,loss:0.3396
# epoch:20,loss:0.3198
# epoch:20,loss:0.8429
# epoch:20,loss:0.3896
# epoch:20,loss:0.9798
# epoch:20,loss:0.4976
# epoch:20,loss:0.3557
# epoch:20,loss:1.5899
# ============================================
# 准确率由： tensor(0.7868) 上升至： tensor(0.8134) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第20个epoch的识别准确率为：81%
# epoch:21,loss:0.3587
# epoch:21,loss:0.1621
# epoch:21,loss:0.5103
# epoch:21,loss:0.2228
# epoch:21,loss:0.4569
# epoch:21,loss:0.1902
# epoch:21,loss:0.3456
# epoch:21,loss:0.2175
# epoch:21,loss:0.3450
# epoch:21,loss:0.8612
# epoch:21,loss:0.5676
# epoch:21,loss:0.7185
# epoch:21,loss:0.3897
# epoch:21,loss:0.4317
# epoch:21,loss:1.9358
# epoch:21,loss:0.3109
# epoch:21,loss:0.5645
# epoch:21,loss:0.3599
# epoch:21,loss:0.2983
# epoch:21,loss:0.4516
# epoch:21,loss:0.1713
# epoch:21,loss:0.9107
# epoch:21,loss:0.4871
# epoch:21,loss:0.5685
# epoch:21,loss:0.2225
# epoch:21,loss:0.7489
# epoch:21,loss:0.7012
# epoch:21,loss:0.6409
# epoch:21,loss:1.2391
# epoch:21,loss:0.2802
# ============================================
# 准确率由： tensor(0.8134) 上升至： tensor(0.8309) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第21个epoch的识别准确率为：83%
# epoch:22,loss:0.8473
# epoch:22,loss:0.4767
# epoch:22,loss:0.3929
# epoch:22,loss:0.8403
# epoch:22,loss:0.3574
# epoch:22,loss:0.6168
# epoch:22,loss:0.4735
# epoch:22,loss:0.7666
# epoch:22,loss:0.5888
# epoch:22,loss:0.2896
# epoch:22,loss:0.4454
# epoch:22,loss:0.2885
# epoch:22,loss:0.5237
# epoch:22,loss:0.2480
# epoch:22,loss:0.2412
# epoch:22,loss:0.2277
# epoch:22,loss:0.2902
# epoch:22,loss:0.4406
# epoch:22,loss:0.2352
# epoch:22,loss:0.2189
# epoch:22,loss:0.1631
# epoch:22,loss:0.2986
# epoch:22,loss:0.1807
# epoch:22,loss:0.3369
# epoch:22,loss:0.1686
# epoch:22,loss:0.1982
# epoch:22,loss:0.1867
# epoch:22,loss:0.1978
# epoch:22,loss:0.4188
# epoch:22,loss:0.1641
# ============================================
# 准确率由： tensor(0.8309) 上升至： tensor(0.8474) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第22个epoch的识别准确率为：84%
# epoch:23,loss:0.2764
# epoch:23,loss:0.2277
# epoch:23,loss:0.9648
# epoch:23,loss:0.8772
# epoch:23,loss:0.2863
# epoch:23,loss:0.8109
# epoch:23,loss:0.1196
# epoch:23,loss:0.3588
# epoch:23,loss:0.4312
# epoch:23,loss:0.2688
# epoch:23,loss:0.3644
# epoch:23,loss:0.4059
# epoch:23,loss:0.4033
# epoch:23,loss:0.2149
# epoch:23,loss:0.2790
# epoch:23,loss:0.2539
# epoch:23,loss:0.4347
# epoch:23,loss:0.4531
# epoch:23,loss:0.5668
# epoch:23,loss:0.2721
# epoch:23,loss:0.1672
# epoch:23,loss:0.4395
# epoch:23,loss:0.7783
# epoch:23,loss:0.1915
# epoch:23,loss:0.5081
# epoch:23,loss:0.4532
# epoch:23,loss:0.9763
# epoch:23,loss:0.1903
# epoch:23,loss:0.2864
# epoch:23,loss:0.2742
# ============================================
# 第23个epoch的识别准确率为：83%
# epoch:24,loss:0.4355
# epoch:24,loss:0.2144
# epoch:24,loss:0.2419
# epoch:24,loss:0.6507
# epoch:24,loss:0.2070
# epoch:24,loss:0.2863
# epoch:24,loss:0.5376
# epoch:24,loss:0.2993
# epoch:24,loss:0.5219
# epoch:24,loss:0.4810
# epoch:24,loss:0.2304
# epoch:24,loss:1.2047
# epoch:24,loss:0.1332
# epoch:24,loss:0.1171
# epoch:24,loss:0.2747
# epoch:24,loss:0.6508
# epoch:24,loss:1.7183
# epoch:24,loss:0.7289
# epoch:24,loss:0.2586
# epoch:24,loss:0.4160
# epoch:24,loss:0.2910
# epoch:24,loss:0.4085
# epoch:24,loss:0.6151
# epoch:24,loss:0.6673
# epoch:24,loss:0.2073
# epoch:24,loss:0.4211
# epoch:24,loss:0.3138
# epoch:24,loss:0.2010
# epoch:24,loss:0.1151
# epoch:24,loss:0.1334
# ============================================
# 准确率由： tensor(0.8474) 上升至： tensor(0.8658) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第24个epoch的识别准确率为：86%
# epoch:25,loss:0.3467
# epoch:25,loss:0.1480
# epoch:25,loss:0.2910
# epoch:25,loss:0.2695
# epoch:25,loss:0.1310
# epoch:25,loss:0.3849
# epoch:25,loss:0.5756
# epoch:25,loss:0.3594
# epoch:25,loss:0.1775
# epoch:25,loss:0.2948
# epoch:25,loss:0.3318
# epoch:25,loss:0.1586
# epoch:25,loss:0.7994
# epoch:25,loss:0.4574
# epoch:25,loss:0.2478
# epoch:25,loss:0.2769
# epoch:25,loss:0.2224
# epoch:25,loss:0.2835
# epoch:25,loss:0.3124
# epoch:25,loss:0.3674
# epoch:25,loss:0.3045
# epoch:25,loss:0.1468
# epoch:25,loss:0.2415
# epoch:25,loss:0.8128
# epoch:25,loss:0.8250
# epoch:25,loss:0.2471
# epoch:25,loss:0.1392
# epoch:25,loss:0.0898
# epoch:25,loss:0.4397
# epoch:25,loss:0.1998
# ============================================
# 准确率由： tensor(0.8658) 上升至： tensor(0.8732) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第25个epoch的识别准确率为：87%
# epoch:26,loss:0.2288
# epoch:26,loss:0.2388
# epoch:26,loss:0.1399
# epoch:26,loss:0.0704
# epoch:26,loss:0.2472
# epoch:26,loss:0.1443
# epoch:26,loss:0.2502
# epoch:26,loss:0.0983
# epoch:26,loss:0.2149
# epoch:26,loss:0.2254
# epoch:26,loss:0.1170
# epoch:26,loss:0.2346
# epoch:26,loss:0.1838
# epoch:26,loss:0.3517
# epoch:26,loss:0.2969
# epoch:26,loss:0.4469
# epoch:26,loss:0.4330
# epoch:26,loss:0.1725
# epoch:26,loss:0.5730
# epoch:26,loss:0.0956
# epoch:26,loss:0.1122
# epoch:26,loss:0.3453
# epoch:26,loss:0.4040
# epoch:26,loss:0.5796
# epoch:26,loss:0.3365
# epoch:26,loss:0.3390
# epoch:26,loss:0.3835
# epoch:26,loss:0.1127
# epoch:26,loss:0.2328
# epoch:26,loss:0.4161
# ============================================
# 准确率由： tensor(0.8732) 上升至： tensor(0.8897) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第26个epoch的识别准确率为：88%
# epoch:27,loss:0.2254
# epoch:27,loss:0.1532
# epoch:27,loss:0.2120
# epoch:27,loss:0.1395
# epoch:27,loss:0.3086
# epoch:27,loss:0.1782
# epoch:27,loss:0.1742
# epoch:27,loss:0.1719
# epoch:27,loss:0.2740
# epoch:27,loss:0.2664
# epoch:27,loss:0.9260
# epoch:27,loss:0.2152
# epoch:27,loss:0.3291
# epoch:27,loss:0.7964
# epoch:27,loss:0.7348
# epoch:27,loss:0.4942
# epoch:27,loss:0.3137
# epoch:27,loss:0.1818
# epoch:27,loss:0.3264
# epoch:27,loss:0.4602
# epoch:27,loss:0.4083
# epoch:27,loss:0.3246
# epoch:27,loss:0.1589
# epoch:27,loss:0.3514
# epoch:27,loss:0.0886
# epoch:27,loss:0.3914
# epoch:27,loss:0.5323
# epoch:27,loss:0.0755
# epoch:27,loss:0.1543
# epoch:27,loss:0.1440
# ============================================
# 准确率由： tensor(0.8897) 上升至： tensor(0.8906) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第27个epoch的识别准确率为：89%
# epoch:28,loss:0.0581
# epoch:28,loss:0.3810
# epoch:28,loss:0.1421
# epoch:28,loss:0.1033
# epoch:28,loss:0.2447
# epoch:28,loss:0.1875
# epoch:28,loss:0.3132
# epoch:28,loss:0.8159
# epoch:28,loss:0.4275
# epoch:28,loss:0.0442
# epoch:28,loss:0.1467
# epoch:28,loss:0.1628
# epoch:28,loss:0.6114
# epoch:28,loss:0.0901
# epoch:28,loss:0.8361
# epoch:28,loss:0.1181
# epoch:28,loss:0.3316
# epoch:28,loss:0.1314
# epoch:28,loss:0.1430
# epoch:28,loss:0.1486
# epoch:28,loss:0.1975
# epoch:28,loss:0.5045
# epoch:28,loss:0.0892
# epoch:28,loss:0.1266
# epoch:28,loss:0.4020
# epoch:28,loss:0.4127
# epoch:28,loss:0.2183
# epoch:28,loss:0.1158
# epoch:28,loss:0.6533
# epoch:28,loss:1.2740
# ============================================
# 准确率由： tensor(0.8906) 上升至： tensor(0.8925) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第28个epoch的识别准确率为：89%
# epoch:29,loss:0.0345
# epoch:29,loss:0.3854
# epoch:29,loss:0.0387
# epoch:29,loss:0.2752
# epoch:29,loss:0.0798
# epoch:29,loss:0.1821
# epoch:29,loss:0.4490
# epoch:29,loss:0.1330
# epoch:29,loss:0.1268
# epoch:29,loss:0.8266
# epoch:29,loss:0.1620
# epoch:29,loss:0.1182
# epoch:29,loss:0.2803
# epoch:29,loss:0.2340
# epoch:29,loss:0.1709
# epoch:29,loss:0.3993
# epoch:29,loss:0.1422
# epoch:29,loss:0.0934
# epoch:29,loss:0.2146
# epoch:29,loss:0.2820
# epoch:29,loss:0.1092
# epoch:29,loss:0.4019
# epoch:29,loss:0.2901
# epoch:29,loss:0.0261
# epoch:29,loss:0.1361
# epoch:29,loss:0.0815
# epoch:29,loss:0.2349
# epoch:29,loss:0.2909
# epoch:29,loss:0.7256
# epoch:29,loss:2.7332
# ============================================
# 准确率由： tensor(0.8925) 上升至： tensor(0.9210) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第29个epoch的识别准确率为：92%
# epoch:30,loss:0.1861
# epoch:30,loss:0.5925
# epoch:30,loss:0.0674
# epoch:30,loss:0.1552
# epoch:30,loss:0.1193
# epoch:30,loss:0.0406
# epoch:30,loss:0.0893
# epoch:30,loss:0.0808
# epoch:30,loss:0.2465
# epoch:30,loss:0.2391
# epoch:30,loss:0.3146
# epoch:30,loss:0.1418
# epoch:30,loss:0.1954
# epoch:30,loss:0.4778
# epoch:30,loss:0.8036
# epoch:30,loss:0.1227
# epoch:30,loss:0.0603
# epoch:30,loss:0.3954
# epoch:30,loss:0.0398
# epoch:30,loss:0.1002
# epoch:30,loss:0.4430
# epoch:30,loss:0.1949
# epoch:30,loss:0.1084
# epoch:30,loss:0.4977
# epoch:30,loss:0.1939
# epoch:30,loss:0.3360
# epoch:30,loss:0.3508
# epoch:30,loss:1.1788
# epoch:30,loss:0.1334
# epoch:30,loss:0.2825
# ============================================
# 第30个epoch的识别准确率为：91%
# epoch:31,loss:0.4275
# epoch:31,loss:0.1853
# epoch:31,loss:0.8777
# epoch:31,loss:0.0264
# epoch:31,loss:0.3061
# epoch:31,loss:0.2182
# epoch:31,loss:0.4476
# epoch:31,loss:0.0987
# epoch:31,loss:0.0730
# epoch:31,loss:0.1267
# epoch:31,loss:0.0451
# epoch:31,loss:0.5829
# epoch:31,loss:0.0459
# epoch:31,loss:0.5429
# epoch:31,loss:0.0534
# epoch:31,loss:0.0830
# epoch:31,loss:0.1570
# epoch:31,loss:0.2786
# epoch:31,loss:0.1179
# epoch:31,loss:0.1051
# epoch:31,loss:0.1677
# epoch:31,loss:0.4089
# epoch:31,loss:0.1888
# epoch:31,loss:0.2568
# epoch:31,loss:0.1066
# epoch:31,loss:0.2214
# epoch:31,loss:0.0878
# epoch:31,loss:0.6691
# epoch:31,loss:0.2077
# epoch:31,loss:0.0664
# ============================================
# 第31个epoch的识别准确率为：90%
# epoch:32,loss:0.1079
# epoch:32,loss:0.0625
# epoch:32,loss:0.0412
# epoch:32,loss:0.0376
# epoch:32,loss:0.0342
# epoch:32,loss:0.1931
# epoch:32,loss:0.1073
# epoch:32,loss:0.0129
# epoch:32,loss:0.4830
# epoch:32,loss:0.0566
# epoch:32,loss:0.4471
# epoch:32,loss:0.2477
# epoch:32,loss:0.0288
# epoch:32,loss:0.3419
# epoch:32,loss:0.6060
# epoch:32,loss:0.0481
# epoch:32,loss:0.1336
# epoch:32,loss:0.1620
# epoch:32,loss:0.0499
# epoch:32,loss:0.0468
# epoch:32,loss:0.1727
# epoch:32,loss:0.0547
# epoch:32,loss:0.4965
# epoch:32,loss:0.2108
# epoch:32,loss:0.0327
# epoch:32,loss:0.0306
# epoch:32,loss:0.0467
# epoch:32,loss:0.0350
# epoch:32,loss:0.2462
# epoch:32,loss:0.1322
# ============================================
# 准确率由： tensor(0.9210) 上升至： tensor(0.9403) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第32个epoch的识别准确率为：94%
# epoch:33,loss:0.0348
# epoch:33,loss:0.0414
# epoch:33,loss:0.3325
# epoch:33,loss:0.3004
# epoch:33,loss:0.1103
# epoch:33,loss:0.0634
# epoch:33,loss:0.1807
# epoch:33,loss:0.1096
# epoch:33,loss:0.0994
# epoch:33,loss:0.1791
# epoch:33,loss:0.5595
# epoch:33,loss:0.0625
# epoch:33,loss:0.1528
# epoch:33,loss:0.0665
# epoch:33,loss:0.0611
# epoch:33,loss:0.0488
# epoch:33,loss:0.2693
# epoch:33,loss:0.0718
# epoch:33,loss:0.0579
# epoch:33,loss:0.1581
# epoch:33,loss:0.1894
# epoch:33,loss:0.1957
# epoch:33,loss:0.0481
# epoch:33,loss:0.0270
# epoch:33,loss:0.0652
# epoch:33,loss:0.1018
# epoch:33,loss:0.0755
# epoch:33,loss:0.0755
# epoch:33,loss:1.0289
# epoch:33,loss:0.0929
# ============================================
# 第33个epoch的识别准确率为：92%
# epoch:34,loss:0.1089
# epoch:34,loss:0.0388
# epoch:34,loss:0.1715
# epoch:34,loss:0.3693
# epoch:34,loss:0.1235
# epoch:34,loss:0.2185
# epoch:34,loss:0.4265
# epoch:34,loss:0.1267
# epoch:34,loss:0.1242
# epoch:34,loss:0.3040
# epoch:34,loss:0.2701
# epoch:34,loss:0.2222
# epoch:34,loss:0.0473
# epoch:34,loss:0.0412
# epoch:34,loss:0.3155
# epoch:34,loss:0.0193
# epoch:34,loss:0.0989
# epoch:34,loss:0.3018
# epoch:34,loss:0.0528
# epoch:34,loss:0.4919
# epoch:34,loss:0.1768
# epoch:34,loss:0.7827
# epoch:34,loss:0.2072
# epoch:34,loss:0.1493
# epoch:34,loss:0.6354
# epoch:34,loss:0.4203
# epoch:34,loss:0.0291
# epoch:34,loss:0.1900
# epoch:34,loss:0.0563
# epoch:34,loss:0.4967
# ============================================
# 第34个epoch的识别准确率为：93%
# epoch:35,loss:0.0781
# epoch:35,loss:0.0415
# epoch:35,loss:0.0876
# epoch:35,loss:0.0361
# epoch:35,loss:0.0274
# epoch:35,loss:0.0226
# epoch:35,loss:0.0244
# epoch:35,loss:0.1767
# epoch:35,loss:0.1695
# epoch:35,loss:0.0110
# epoch:35,loss:0.3729
# epoch:35,loss:0.0194
# epoch:35,loss:0.1306
# epoch:35,loss:0.3947
# epoch:35,loss:0.0623
# epoch:35,loss:0.6739
# epoch:35,loss:0.2283
# epoch:35,loss:0.2096
# epoch:35,loss:0.5045
# epoch:35,loss:0.0516
# epoch:35,loss:0.3804
# epoch:35,loss:0.6943
# epoch:35,loss:0.4150
# epoch:35,loss:0.8972
# epoch:35,loss:0.0303
# epoch:35,loss:0.0442
# epoch:35,loss:0.3487
# epoch:35,loss:0.0236
# epoch:35,loss:0.0937
# epoch:35,loss:0.1318
# ============================================
# 第35个epoch的识别准确率为：93%
# epoch:36,loss:0.4810
# epoch:36,loss:0.2324
# epoch:36,loss:0.1117
# epoch:36,loss:0.1598
# epoch:36,loss:0.1267
# epoch:36,loss:0.2035
# epoch:36,loss:0.1936
# epoch:36,loss:0.0964
# epoch:36,loss:0.0560
# epoch:36,loss:0.0501
# epoch:36,loss:0.0230
# epoch:36,loss:0.0867
# epoch:36,loss:0.0676
# epoch:36,loss:0.3162
# epoch:36,loss:0.1656
# epoch:36,loss:0.3847
# epoch:36,loss:0.0239
# epoch:36,loss:0.2398
# epoch:36,loss:0.1846
# epoch:36,loss:0.0736
# epoch:36,loss:0.0758
# epoch:36,loss:0.1869
# epoch:36,loss:0.4431
# epoch:36,loss:0.4274
# epoch:36,loss:0.2734
# epoch:36,loss:0.0639
# epoch:36,loss:0.1933
# epoch:36,loss:0.1658
# epoch:36,loss:0.0565
# epoch:36,loss:0.1940
# ============================================
# 第36个epoch的识别准确率为：93%
# epoch:37,loss:1.1365
# epoch:37,loss:0.1138
# epoch:37,loss:0.0342
# epoch:37,loss:0.0178
# epoch:37,loss:0.0503
# epoch:37,loss:0.0446
# epoch:37,loss:0.0106
# epoch:37,loss:0.5465
# epoch:37,loss:0.0695
# epoch:37,loss:0.0591
# epoch:37,loss:0.3175
# epoch:37,loss:0.0447
# epoch:37,loss:0.2611
# epoch:37,loss:0.0608
# epoch:37,loss:0.0655
# epoch:37,loss:0.0277
# epoch:37,loss:0.1072
# epoch:37,loss:0.4499
# epoch:37,loss:0.0304
# epoch:37,loss:0.0516
# epoch:37,loss:0.4054
# epoch:37,loss:0.0119
# epoch:37,loss:0.1046
# epoch:37,loss:0.0268
# epoch:37,loss:0.1280
# epoch:37,loss:0.0162
# epoch:37,loss:0.1804
# epoch:37,loss:0.0890
# epoch:37,loss:0.3231
# epoch:37,loss:0.9065
# ============================================
# 第37个epoch的识别准确率为：92%
# epoch:38,loss:0.3101
# epoch:38,loss:0.1030
# epoch:38,loss:0.2017
# epoch:38,loss:0.0461
# epoch:38,loss:0.0405
# epoch:38,loss:0.1484
# epoch:38,loss:0.2277
# epoch:38,loss:0.3311
# epoch:38,loss:0.0141
# epoch:38,loss:0.2899
# epoch:38,loss:0.1545
# epoch:38,loss:0.0383
# epoch:38,loss:0.1951
# epoch:38,loss:0.1703
# epoch:38,loss:0.6466
# epoch:38,loss:0.1548
# epoch:38,loss:0.2771
# epoch:38,loss:0.0884
# epoch:38,loss:0.0814
# epoch:38,loss:0.0471
# epoch:38,loss:0.0293
# epoch:38,loss:0.0563
# epoch:38,loss:0.0315
# epoch:38,loss:0.2145
# epoch:38,loss:0.0264
# epoch:38,loss:0.0597
# epoch:38,loss:0.0670
# epoch:38,loss:0.0430
# epoch:38,loss:0.1410
# epoch:38,loss:0.0413
# ============================================
# 第38个epoch的识别准确率为：93%
# epoch:39,loss:0.0590
# epoch:39,loss:0.1074
# epoch:39,loss:0.0873
# epoch:39,loss:0.0299
# epoch:39,loss:0.1354
# epoch:39,loss:0.0663
# epoch:39,loss:1.2297
# epoch:39,loss:0.0471
# epoch:39,loss:0.0338
# epoch:39,loss:0.1859
# epoch:39,loss:0.1025
# epoch:39,loss:0.1296
# epoch:39,loss:0.0375
# epoch:39,loss:0.3571
# epoch:39,loss:0.0975
# epoch:39,loss:0.9621
# epoch:39,loss:0.2198
# epoch:39,loss:0.0129
# epoch:39,loss:0.1450
# epoch:39,loss:0.1384
# epoch:39,loss:0.0706
# epoch:39,loss:0.2787
# epoch:39,loss:0.0868
# epoch:39,loss:0.2231
# epoch:39,loss:0.0482
# epoch:39,loss:0.1067
# epoch:39,loss:0.2258
# epoch:39,loss:0.1727
# epoch:39,loss:0.1738
# epoch:39,loss:0.1218
# ============================================
# 准确率由： tensor(0.9403) 上升至： tensor(0.9458) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第39个epoch的识别准确率为：94%
# epoch:40,loss:0.2992
# epoch:40,loss:0.0139
# epoch:40,loss:0.1418
# epoch:40,loss:0.2818
# epoch:40,loss:0.1853
# epoch:40,loss:0.0134
# epoch:40,loss:0.1358
# epoch:40,loss:0.0201
# epoch:40,loss:0.0062
# epoch:40,loss:0.3522
# epoch:40,loss:0.3103
# epoch:40,loss:0.0537
# epoch:40,loss:0.2325
# epoch:40,loss:0.1603
# epoch:40,loss:0.3860
# epoch:40,loss:0.0515
# epoch:40,loss:0.0150
# epoch:40,loss:0.6045
# epoch:40,loss:0.3826
# epoch:40,loss:0.0379
# epoch:40,loss:0.0623
# epoch:40,loss:0.2052
# epoch:40,loss:0.1770
# epoch:40,loss:0.0309
# epoch:40,loss:0.1520
# epoch:40,loss:0.1026
# epoch:40,loss:0.1630
# epoch:40,loss:0.0145
# epoch:40,loss:0.2010
# epoch:40,loss:0.3163
# ============================================
# 准确率由： tensor(0.9458) 上升至： tensor(0.9513) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第40个epoch的识别准确率为：95%
# epoch:41,loss:0.0089
# epoch:41,loss:0.2286
# epoch:41,loss:0.2253
# epoch:41,loss:0.3549
# epoch:41,loss:0.2011
# epoch:41,loss:0.0506
# epoch:41,loss:0.0849
# epoch:41,loss:0.1343
# epoch:41,loss:0.0875
# epoch:41,loss:0.0353
# epoch:41,loss:0.1652
# epoch:41,loss:0.0566
# epoch:41,loss:0.0775
# epoch:41,loss:0.4007
# epoch:41,loss:0.1189
# epoch:41,loss:0.0253
# epoch:41,loss:0.0123
# epoch:41,loss:0.2045
# epoch:41,loss:0.0381
# epoch:41,loss:0.4417
# epoch:41,loss:0.1675
# epoch:41,loss:0.0563
# epoch:41,loss:0.1298
# epoch:41,loss:0.0115
# epoch:41,loss:0.0317
# epoch:41,loss:0.0107
# epoch:41,loss:0.0788
# epoch:41,loss:0.0495
# epoch:41,loss:0.0806
# epoch:41,loss:0.0663
# ============================================
# 准确率由： tensor(0.9513) 上升至： tensor(0.9632) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第41个epoch的识别准确率为：96%
# epoch:42,loss:0.0192
# epoch:42,loss:0.0809
# epoch:42,loss:0.6000
# epoch:42,loss:0.0187
# epoch:42,loss:0.0116
# epoch:42,loss:0.3240
# epoch:42,loss:0.1491
# epoch:42,loss:0.0942
# epoch:42,loss:0.1307
# epoch:42,loss:0.3716
# epoch:42,loss:0.0685
# epoch:42,loss:1.0162
# epoch:42,loss:0.0230
# epoch:42,loss:0.0210
# epoch:42,loss:0.2545
# epoch:42,loss:0.7735
# epoch:42,loss:0.0969
# epoch:42,loss:1.3324
# epoch:42,loss:0.2865
# epoch:42,loss:0.1700
# epoch:42,loss:0.2277
# epoch:42,loss:0.0391
# epoch:42,loss:0.1053
# epoch:42,loss:0.0213
# epoch:42,loss:0.0271
# epoch:42,loss:0.0245
# epoch:42,loss:0.2447
# epoch:42,loss:0.0128
# epoch:42,loss:0.0279
# epoch:42,loss:0.0339
# ============================================
# 第42个epoch的识别准确率为：95%
# epoch:43,loss:0.0221
# epoch:43,loss:0.0625
# epoch:43,loss:0.0919
# epoch:43,loss:0.0778
# epoch:43,loss:0.0973
# epoch:43,loss:0.0780
# epoch:43,loss:0.1066
# epoch:43,loss:0.0714
# epoch:43,loss:0.0552
# epoch:43,loss:0.1103
# epoch:43,loss:0.2631
# epoch:43,loss:0.0842
# epoch:43,loss:0.0187
# epoch:43,loss:0.6347
# epoch:43,loss:0.0595
# epoch:43,loss:0.2191
# epoch:43,loss:0.0127
# epoch:43,loss:0.0645
# epoch:43,loss:0.0317
# epoch:43,loss:0.0479
# epoch:43,loss:0.0292
# epoch:43,loss:0.3960
# epoch:43,loss:0.0720
# epoch:43,loss:0.0121
# epoch:43,loss:0.0201
# epoch:43,loss:0.0029
# epoch:43,loss:0.0214
# epoch:43,loss:0.0082
# epoch:43,loss:0.1580
# epoch:43,loss:0.0289
# ============================================
# 第43个epoch的识别准确率为：95%
# epoch:44,loss:0.1126
# epoch:44,loss:0.0888
# epoch:44,loss:0.0836
# epoch:44,loss:0.0097
# epoch:44,loss:0.2279
# epoch:44,loss:0.5983
# epoch:44,loss:0.2193
# epoch:44,loss:0.0204
# epoch:44,loss:0.2803
# epoch:44,loss:0.0728
# epoch:44,loss:0.3731
# epoch:44,loss:0.0181
# epoch:44,loss:0.1900
# epoch:44,loss:0.1172
# epoch:44,loss:0.2768
# epoch:44,loss:0.5310
# epoch:44,loss:0.0117
# epoch:44,loss:0.0043
# epoch:44,loss:0.0061
# epoch:44,loss:0.0343
# epoch:44,loss:0.0316
# epoch:44,loss:0.0521
# epoch:44,loss:0.0606
# epoch:44,loss:1.2344
# epoch:44,loss:0.0098
# epoch:44,loss:0.1085
# epoch:44,loss:0.1599
# epoch:44,loss:0.2380
# epoch:44,loss:0.4963
# epoch:44,loss:0.0820
# ============================================
# 第44个epoch的识别准确率为：95%
# epoch:45,loss:0.1439
# epoch:45,loss:0.0310
# epoch:45,loss:0.1171
# epoch:45,loss:0.0291
# epoch:45,loss:1.0967
# epoch:45,loss:0.1526
# epoch:45,loss:0.1908
# epoch:45,loss:0.0215
# epoch:45,loss:0.0268
# epoch:45,loss:0.2768
# epoch:45,loss:0.0891
# epoch:45,loss:0.0883
# epoch:45,loss:0.2450
# epoch:45,loss:0.0124
# epoch:45,loss:0.0528
# epoch:45,loss:0.0850
# epoch:45,loss:0.1385
# epoch:45,loss:0.0337
# epoch:45,loss:0.0954
# epoch:45,loss:0.0067
# epoch:45,loss:0.0240
# epoch:45,loss:0.0195
# epoch:45,loss:0.0880
# epoch:45,loss:0.1573
# epoch:45,loss:0.3403
# epoch:45,loss:0.0475
# epoch:45,loss:0.3375
# epoch:45,loss:0.0255
# epoch:45,loss:0.7810
# epoch:45,loss:0.0268
# ============================================
# 第45个epoch的识别准确率为：95%
# epoch:46,loss:0.0926
# epoch:46,loss:0.1088
# epoch:46,loss:0.1027
# epoch:46,loss:0.0206
# epoch:46,loss:0.0531
# epoch:46,loss:0.0421
# epoch:46,loss:0.0836
# epoch:46,loss:0.1477
# epoch:46,loss:0.0084
# epoch:46,loss:0.0136
# epoch:46,loss:0.0930
# epoch:46,loss:0.1895
# epoch:46,loss:0.0181
# epoch:46,loss:0.2181
# epoch:46,loss:0.0753
# epoch:46,loss:0.0078
# epoch:46,loss:0.0199
# epoch:46,loss:0.0250
# epoch:46,loss:0.0412
# epoch:46,loss:0.1873
# epoch:46,loss:0.2218
# epoch:46,loss:0.0831
# epoch:46,loss:0.0762
# epoch:46,loss:0.1275
# epoch:46,loss:0.0179
# epoch:46,loss:0.1219
# epoch:46,loss:0.0912
# epoch:46,loss:0.0222
# epoch:46,loss:0.0308
# epoch:46,loss:0.0123
# ============================================
# 准确率由： tensor(0.9632) 上升至： tensor(0.9669) 已更新并保存权值为weights/mobilenetv3_small_best.pkl
# 第46个epoch的识别准确率为：96%
# epoch:47,loss:0.0312
# epoch:47,loss:0.2411
# epoch:47,loss:0.2629
# epoch:47,loss:0.2967
# epoch:47,loss:0.0163
# epoch:47,loss:0.0597
# epoch:47,loss:0.1279
# epoch:47,loss:0.0870
# epoch:47,loss:0.0212
# epoch:47,loss:0.0774
# epoch:47,loss:0.0607
# epoch:47,loss:0.6906
# epoch:47,loss:0.5855
# epoch:47,loss:0.5553
# epoch:47,loss:0.0744
# epoch:47,loss:0.0447
# epoch:47,loss:0.1241
# epoch:47,loss:0.1354
# epoch:47,loss:0.0618
# epoch:47,loss:0.0730
# epoch:47,loss:0.0257
# epoch:47,loss:0.0116
# epoch:47,loss:0.0147
# epoch:47,loss:0.0187
# epoch:47,loss:0.0427
# epoch:47,loss:0.0537
# epoch:47,loss:0.0245
# epoch:47,loss:0.0333
# epoch:47,loss:0.0131
# epoch:47,loss:0.0497
# ============================================
# 第47个epoch的识别准确率为：96%
# epoch:48,loss:0.0287
# epoch:48,loss:0.1091
# epoch:48,loss:0.0246
# epoch:48,loss:0.0883
# epoch:48,loss:0.0848
# epoch:48,loss:0.0655
# epoch:48,loss:0.1268
# epoch:48,loss:0.0126
# epoch:48,loss:0.0043
# epoch:48,loss:0.5845
# epoch:48,loss:0.0221
# epoch:48,loss:0.0220
# epoch:48,loss:0.2875
# epoch:48,loss:0.0261
# epoch:48,loss:0.2959
# epoch:48,loss:0.1304
# epoch:48,loss:0.3109
# epoch:48,loss:0.0629
# epoch:48,loss:0.0567
# epoch:48,loss:0.0312
# epoch:48,loss:0.0045
# epoch:48,loss:0.0103
# epoch:48,loss:0.2088
# epoch:48,loss:0.0057
# epoch:48,loss:0.0078
# epoch:48,loss:0.0715
# epoch:48,loss:0.2829
# epoch:48,loss:0.0142
# epoch:48,loss:0.1108
# epoch:48,loss:0.0365
# ============================================
# 第48个epoch的识别准确率为：95%
# epoch:49,loss:0.0299
# epoch:49,loss:0.1792
# epoch:49,loss:0.0599
# epoch:49,loss:0.0595
# epoch:49,loss:0.0047
# epoch:49,loss:0.1923
# epoch:49,loss:0.0054
# epoch:49,loss:0.2069
# epoch:49,loss:0.0666
# epoch:49,loss:0.1551
# epoch:49,loss:0.0465
# epoch:49,loss:0.0116
# epoch:49,loss:0.0645
# epoch:49,loss:0.0671
# epoch:49,loss:0.0039
# epoch:49,loss:0.0263
# epoch:49,loss:0.0982
# epoch:49,loss:0.0273
# epoch:49,loss:0.3014
# epoch:49,loss:0.0107
# epoch:49,loss:0.1700
# epoch:49,loss:0.2026
# epoch:49,loss:0.0640
# epoch:49,loss:0.0728
# epoch:49,loss:0.0025
# epoch:49,loss:0.0060
# epoch:49,loss:0.0169
# epoch:49,loss:0.5415
# epoch:49,loss:0.0519
# epoch:49,loss:0.1691
# ============================================
# 第49个epoch的识别准确率为：95%
# epoch:50,loss:0.0036
# epoch:50,loss:0.0149
# epoch:50,loss:0.0244
# epoch:50,loss:0.4108
# epoch:50,loss:0.0017
# epoch:50,loss:0.0722
# epoch:50,loss:0.0278
# epoch:50,loss:0.1593
# epoch:50,loss:0.0650
# epoch:50,loss:0.3249
# epoch:50,loss:0.0152
# epoch:50,loss:0.0424
# epoch:50,loss:0.0172
# epoch:50,loss:0.0773
# epoch:50,loss:0.2898
# epoch:50,loss:0.4670
# epoch:50,loss:0.0767
# epoch:50,loss:0.1356
# epoch:50,loss:0.0830
# epoch:50,loss:0.0158
# epoch:50,loss:0.0095
# epoch:50,loss:1.1879
# epoch:50,loss:1.0273
# epoch:50,loss:0.0433
# epoch:50,loss:0.1121
# epoch:50,loss:0.4790
# epoch:50,loss:0.0167
# epoch:50,loss:0.1433
# epoch:50,loss:0.1480
# epoch:50,loss:0.0290
# ============================================
# 第50个epoch的识别准确率为：95%
# 训练完毕，权重已保存为：weights/mobilenetv3_small_last.pkl

# %%
from torchviz import make_dot

small_model = torch.load("./weights/mobilenetv3_small_best.pkl")

params = list(small_model.parameters())
k = 0
for i in params:
        l = 1
        print("该层的结构：" + str(list(i.size())))
        for j in i.size():
                l *= j
        print("该层参数和：" + str(l))
        k = k + l
print("总参数数量和：" + str(k))
# Out:
# 该层的结构：[16, 3, 3, 3]
# 该层参数和：432
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[4, 16]
# 该层参数和：64
# 该层的结构：[16, 4]
# 该层参数和：64
# 该层的结构：[16, 16, 1, 1]
# 该层参数和：256
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16, 1, 3, 3]
# 该层参数和：144
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16, 16, 1, 1]
# 该层参数和：256
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[16]
# 该层参数和：16
# 该层的结构：[72, 16, 1, 1]
# 该层参数和：1152
# 该层的结构：[72]
# 该层参数和：72
# 该层的结构：[72]
# 该层参数和：72
# 该层的结构：[72, 1, 3, 3]
# 该层参数和：648
# 该层的结构：[72]
# 该层参数和：72
# 该层的结构：[72]
# 该层参数和：72
# 该层的结构：[24, 72, 1, 1]
# 该层参数和：1728
# 该层的结构：[24]
# 该层参数和：24
# 该层的结构：[24]
# 该层参数和：24
# 该层的结构：[88, 24, 1, 1]
# 该层参数和：2112
# 该层的结构：[88]
# 该层参数和：88
# 该层的结构：[88]
# 该层参数和：88
# 该层的结构：[88, 1, 3, 3]
# 该层参数和：792
# 该层的结构：[88]
# 该层参数和：88
# 该层的结构：[88]
# 该层参数和：88
# 该层的结构：[24, 88, 1, 1]
# 该层参数和：2112
# 该层的结构：[24]
# 该层参数和：24
# 该层的结构：[24]
# 该层参数和：24
# 该层的结构：[24, 96]
# 该层参数和：2304
# 该层的结构：[96, 24]
# 该层参数和：2304
# 该层的结构：[96, 24, 1, 1]
# 该层参数和：2304
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96, 1, 5, 5]
# 该层参数和：2400
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[40, 96, 1, 1]
# 该层参数和：3840
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[60, 240]
# 该层参数和：14400
# 该层的结构：[240, 60]
# 该层参数和：14400
# 该层的结构：[240, 40, 1, 1]
# 该层参数和：9600
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240, 1, 5, 5]
# 该层参数和：6000
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[40, 240, 1, 1]
# 该层参数和：9600
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[60, 240]
# 该层参数和：14400
# 该层的结构：[240, 60]
# 该层参数和：14400
# 该层的结构：[240, 40, 1, 1]
# 该层参数和：9600
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240, 1, 5, 5]
# 该层参数和：6000
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[240]
# 该层参数和：240
# 该层的结构：[40, 240, 1, 1]
# 该层参数和：9600
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[40]
# 该层参数和：40
# 该层的结构：[30, 120]
# 该层参数和：3600
# 该层的结构：[120, 30]
# 该层参数和：3600
# 该层的结构：[120, 40, 1, 1]
# 该层参数和：4800
# 该层的结构：[120]
# 该层参数和：120
# 该层的结构：[120]
# 该层参数和：120
# 该层的结构：[120, 1, 5, 5]
# 该层参数和：3000
# 该层的结构：[120]
# 该层参数和：120
# 该层的结构：[120]
# 该层参数和：120
# 该层的结构：[48, 120, 1, 1]
# 该层参数和：5760
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[48, 40, 1, 1]
# 该层参数和：1920
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[36, 144]
# 该层参数和：5184
# 该层的结构：[144, 36]
# 该层参数和：5184
# 该层的结构：[144, 48, 1, 1]
# 该层参数和：6912
# 该层的结构：[144]
# 该层参数和：144
# 该层的结构：[144]
# 该层参数和：144
# 该层的结构：[144, 1, 5, 5]
# 该层参数和：3600
# 该层的结构：[144]
# 该层参数和：144
# 该层的结构：[144]
# 该层参数和：144
# 该层的结构：[48, 144, 1, 1]
# 该层参数和：6912
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[48]
# 该层参数和：48
# 该层的结构：[72, 288]
# 该层参数和：20736
# 该层的结构：[288, 72]
# 该层参数和：20736
# 该层的结构：[288, 48, 1, 1]
# 该层参数和：13824
# 该层的结构：[288]
# 该层参数和：288
# 该层的结构：[288]
# 该层参数和：288
# 该层的结构：[288, 1, 5, 5]
# 该层参数和：7200
# 该层的结构：[288]
# 该层参数和：288
# 该层的结构：[288]
# 该层参数和：288
# 该层的结构：[96, 288, 1, 1]
# 该层参数和：27648
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[144, 576]
# 该层参数和：82944
# 该层的结构：[576, 144]
# 该层参数和：82944
# 该层的结构：[576, 96, 1, 1]
# 该层参数和：55296
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576, 1, 5, 5]
# 该层参数和：14400
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[96, 576, 1, 1]
# 该层参数和：55296
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[144, 576]
# 该层参数和：82944
# 该层的结构：[576, 144]
# 该层参数和：82944
# 该层的结构：[576, 96, 1, 1]
# 该层参数和：55296
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576, 1, 5, 5]
# 该层参数和：14400
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[96, 576, 1, 1]
# 该层参数和：55296
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[96]
# 该层参数和：96
# 该层的结构：[576, 96, 1, 1]
# 该层参数和：55296
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[576]
# 该层参数和：576
# 该层的结构：[1280, 576, 1, 1]
# 该层参数和：737280
# 该层的结构：[1280]
# 该层参数和：1280
# 该层的结构：[17, 1280, 1, 1]
# 该层参数和：21760
# 该层的结构：[17]
# 该层参数和：17
# 总参数数量和：1681161

# %% [markdown]
# ### inference

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

split_dir=os.path.join(".","data","splitData")
test_dir=os.path.join(split_dir,"test")
# test_dir = os.path.join(".", "data", "rawData")

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

test_data = flowerDataset(data_dir=test_dir, transform=test_transform)
test_dataLoader = DataLoader(dataset=test_data, batch_size=BATCH_SIZE, shuffle=False)

# %%
small_model = torch.load("./weights/mobilenetv3_small_best.pkl")
small_model.eval()
correct = 0.
total=0.
with torch.no_grad():
    for i, data in enumerate(test_dataLoader):
        img, label = data
        img = Variable(img)
        label = Variable(label)
        img, label = img.to(device), label.to(device)
        print("label:", label)
        output = small_model(img)
        _, predicted = torch.max(output.data, 1)
        print("predict:", predicted)
        total += label.size(0)
        correct += (predicted == label).sum()

acc = correct/total * 100.
print("Total:", total)
print("Accuracy:{}%".format(acc))
# Out:
# label: tensor([15, 15, 15, 15, 15, 15, 15, 15,  9,  9,  9,  9])
# predict: tensor([10, 15, 15, 15,  1, 15, 10, 10,  9,  9,  9,  9])
# label: tensor([9, 9, 9, 9, 2, 2, 2, 2, 2, 2, 2, 2])
# predict: tensor([12,  5,  9, 14,  1, 13,  2,  8,  2,  2,  2, 13])
# label: tensor([4, 4, 4, 4, 4, 4, 4, 4, 0, 0, 0, 0])
# predict: tensor([ 4, 10,  4, 10,  8,  4,  8,  5,  0, 14,  0,  0])
# label: tensor([ 0,  0,  0,  0, 11, 11, 11, 11, 11, 11, 11, 11])
# predict: tensor([ 7,  0,  0, 15, 11, 11, 11, 11,  4, 11, 12, 11])
# label: tensor([8, 8, 8, 8, 8, 8, 8, 8, 3, 3, 3, 3])
# predict: tensor([ 8,  8,  8,  8,  8, 15,  7,  8,  1, 16,  2,  3])
# label: tensor([ 3,  3,  3,  3, 13, 13, 13, 13, 13, 13, 13, 13])
# predict: tensor([ 3,  2,  1,  5, 13,  2,  7, 13,  7,  7, 13,  2])
# label: tensor([ 5,  5,  5,  5,  5,  5,  5,  5, 16, 16, 16, 16])
# predict: tensor([14,  5,  5,  5, 15,  5,  1,  5, 10, 16,  1,  4])
# label: tensor([16, 16, 16, 16,  1,  1,  1,  1,  1,  1,  1,  1])
# predict: tensor([16,  0, 16, 16,  1, 15, 13,  1,  1,  8, 13, 15])
# label: tensor([ 7,  7,  7,  7,  7,  7,  7,  7, 14, 14, 14, 14])
# predict: tensor([13, 13, 15,  7, 14,  7,  1,  7, 14, 14, 13, 11])
# label: tensor([14, 14, 14, 14, 12, 12, 12, 12, 12, 12, 12, 12])
# predict: tensor([14,  7, 14, 14,  0, 12,  7, 12, 13, 11, 11, 12])
# label: tensor([ 6,  6,  6,  6,  6,  6,  6,  6, 10, 10, 10, 10])
# predict: tensor([ 6,  6,  6,  6,  6,  6,  6,  6,  5, 10,  3, 10])
# label: tensor([10, 10, 10, 10])
# predict: tensor([10, 10, 15, 10])
# Total: 136.0
# Accuracy:54.41176223754883%

# %% [markdown]
# ### quantization

# %%
small_model.state_dict()
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[-1.8063e-02, -1.5637e-01,  1.5067e-02],
#                         [ 5.6862e-02,  1.9757e-02,  9.9112e-02],
#                         [-9.4381e-02, -3.3128e-02,  9.1726e-02]],
#
#                        [[-5.6205e-02,  1.2083e-01,  8.2373e-05],
#                         [ 1.9790e-01, -1.0717e-02,  2.0258e-01],
#                         [ 2.8617e-02,  5.2607e-02,  4.5153e-02]],
#
#                        [[ 1.7814e-01,  5.4553e-03,  1.6671e-01],
#                         [-6.8266e-03,  7.3133e-02, -1.8044e-01],
#                         [ 5.0680e-03,  4.7459e-02,  4.2604e-02]]],
#
#
#                       [[[-2.2063e-02,  4.6733e-02, -2.1609e-03],
#                        [[ 0.1627]],
#
#                        [[-0.1209]],
#
#                        [[ 0.0400]],
#
#                        [[-0.2273]],
#
#                        [[ 0.0773]],
#
#                        [[ 0.1840]],
#
#                        [[ 0.0457]],
#
#                        [[-0.0497]],
#
#                        [[-0.0669]],
#
#                        [[-0.0531]],
#
#                        [[ 0.1900]],
#
#                        [[-0.0862]],
#
#                        [[-0.1750]],
#
#                        [[-0.1006]]],
#
#
#                       [[[ 0.2010]],
#
#                        [[ 0.1779]],
#
#                        [[ 0.1548]],
#
#                        [[ 0.1117]],
#
#                        [[ 0.1780]],
#
#                        [[ 0.0289]],
#
#                        [[ 0.0550]],
#
#                        [[-0.0148]],
#
#                        [[-0.1732]],
#
#                        [[-0.0275]],
#
#                        [[ 0.1925]],
#
#                        [[ 0.2422]],
#
#                        [[ 0.0922]],
#
#                        [[ 0.0149]],
#
#                        [[ 0.2087]],
#
#                        [[-0.0467]]],
#
#
#                       [[[ 0.0405]],
#
#                        [[ 0.2315]],
#
#                        [[ 0.2365]],
#
#                        [[-0.1857]],
#
#                        [[ 0.0567]],
#
#                        [[-0.0821]],
#
#                        [[-0.2512]],
#
#                        [[-0.1374]],
#
#                        [[-0.2450]],
#
#                        [[-0.0172]],
#
#                        [[-0.1376]],
#
#                        [[ 0.2031]],
#
#                        [[ 0.2069]],
#
#                        [[-0.2039]],
#
#                        [[-0.2196]],
#
#                        [[ 0.1370]]],
#
#
#                       [[[-0.0855]],
#
#                        [[ 0.1275]],
#
#                        [[ 0.2248]],
#
#                        [[ 0.1530]],
#
#                        [[-0.0867]],
#
#                        [[-0.0203]],
#
#                        [[ 0.1742]],
#
#                        [[ 0.0070]],
#
#                        [[ 0.0747]],
#
#                        [[-0.0122]],
#
#                        [[ 0.2411]],
#
#                        [[ 0.0279]],
#
#                        [[-0.1301]],
#
#                        [[-0.1731]],
#
#                        [[-0.2123]],
#
#                        [[ 0.2116]]],
#
#
#                       [[[-0.0774]],
#
#                        [[-0.2320]],
#
#                        [[ 0.1242]],
#
#                        [[-0.0679]],
#
#                        [[ 0.0608]],
#
#                        [[ 0.2375]],
#
#                        [[-0.2294]],
#
#                        [[ 0.0514]],
#
#                        [[ 0.1412]],
#
#                        [[-0.2020]],
#
#                        [[-0.1035]],
#
#                        [[ 0.1011]],
#
#                        [[-0.2501]],
#
#                        [[ 0.1093]],
#
#                        [[-0.1692]],
#
#                        [[ 0.0187]]],
#
#
#                       [[[ 0.2260]],
#
#                        [[-0.1194]],
#
#                        [[-0.0706]],
#
#                        [[ 0.2106]],
#
#                        [[ 0.2266]],
#
#                        [[ 0.0753]],
#
#                        [[-0.1242]],
#
#                        [[ 0.1678]],
#
#                        [[-0.1204]],
#
#                        [[ 0.0706]],
#
#                        [[-0.0067]],
#
#                        [[-0.0980]],
#
#                        [[ 0.0459]],
#
#                        [[ 0.0076]],
#
#                        [[-0.2339]],
#
#                        [[-0.0762]]],
#
#
#                       [[[-0.1849]],
#
#                        [[ 0.0442]],
#
#                        [[-0.1710]],
#
#                        [[-0.1098]],
#
#                        [[-0.0764]],
#
#                        [[-0.0287]],
#
#                        [[ 0.2352]],
#
#                        [[-0.1666]],
#
#                        [[-0.2399]],
#
#                        [[-0.1388]],
#
#                        [[-0.2569]],
#
#                        [[ 0.0503]],
#
#                        [[-0.2455]],
#
#                        [[ 0.0903]],
#
#                        [[ 0.1830]],
#
#                        [[ 0.0955]]],
#
#
#                       [[[-0.0226]],
#
#                        [[ 0.1854]],
#
#                        [[ 0.2284]],
#
#                        [[-0.0253]],
#
#                        [[-0.1204]],
#
#                        [[ 0.1395]],
#
#                        [[ 0.0616]],
#
#                        [[-0.2169]],
#
#                        [[ 0.0700]],
#
#                        [[-0.1975]],
#
#                        [[ 0.1452]],
#
#                        [[ 0.1718]],
#
#                        [[ 0.2563]],
#
#                        [[-0.0724]],
#
#                        [[-0.2268]],
#
#                        [[-0.2461]]],
#
#
#                       [[[-0.1658]],
#
#                        [[ 0.2049]],
#
#                        [[-0.0407]],
#
#                        [[-0.2287]],
#
#                        [[ 0.1409]],
#
#                        [[-0.2059]],
#
#                        [[-0.2240]],
#
#                        [[ 0.0869]],
#
#                        [[-0.0324]],
#
#                        [[ 0.0610]],
#
#                        [[ 0.0797]],
#
#                        [[ 0.2409]],
#
#                        [[ 0.0442]],
#
#                        [[-0.1434]],
#
#                        [[ 0.1426]],
#
#                        [[-0.0306]]],
#
#
#                       [[[ 0.1088]],
#
#                        [[ 0.2175]],
#
#                        [[-0.2350]],
#
#                        [[-0.1809]],
#
#                        [[-0.0475]],
#
#                        [[ 0.1726]],
#
#                        [[-0.1880]],
#
#                        [[-0.0506]],
#
#                        [[-0.2171]],
#
#                        [[-0.0241]],
#
#                        [[-0.1990]],
#
#                        [[ 0.1007]],
#
#                        [[ 0.0502]],
#
#                        [[ 0.1747]],
#
#                        [[ 0.0021]],
#
#                        [[ 0.2009]]],
#
#
#                       [[[ 0.0916]],
#
#                        [[ 0.0376]],
#
#                        [[-0.0677]],
#
#                        [[-0.0502]],
#
#                        [[-0.2277]],
#
#                        [[ 0.1724]],
#
#                        [[-0.1915]],
#
#                        [[-0.0079]],
#
#                        [[-0.0742]],
#
#                        [[ 0.1142]],
#
#                        [[-0.1071]],
#
#                        [[-0.0931]],
#
#                        [[-0.2360]],
#
#                        [[-0.0819]],
#
#                        [[ 0.2409]],
#
#                        [[-0.0449]]],
#
#
#                       [[[-0.0316]],
#
#                        [[-0.2448]],
#
#                        [[-0.1843]],
#
#                        [[-0.0414]],
#
#                        [[ 0.0692]],
#
#                        [[-0.0363]],
#
#                        [[ 0.1607]],
#
#                        [[ 0.1611]],
#
#                        [[ 0.0757]],
#
#                        [[-0.1872]],
#
#                        [[-0.1112]],
#
#                        [[ 0.0054]],
#
#                        [[ 0.1961]],
#
#                        [[ 0.1816]],
#
#                        [[ 0.1139]],
#
#                        [[-0.2207]]],
#
#
#                       [[[-0.1174]],
#
#                        [[-0.0475]],
#
#                        [[-0.2026]],
#
#                        [[-0.0779]],
#
#                        [[-0.0398]],
#
#                        [[-0.1666]],
#
#                        [[ 0.0217]],
#
#                        [[-0.0491]],
#
#                        [[-0.0743]],
#
#                        [[-0.1930]],
#
#                        [[ 0.0686]],
#
#                        [[ 0.1719]],
#
#                        [[ 0.2371]],
#
#                        [[-0.0210]],
#
#                        [[-0.2423]],
#
#                        [[ 0.0068]]],
#
#
#                       [[[-0.0594]],
#
#                        [[ 0.2623]],
#
#                        [[-0.0983]],
#
#                        [[ 0.0090]],
#
#                        [[ 0.1543]],
#
#                        [[ 0.2398]],
#
#                        [[ 0.1188]],
#
#                        [[-0.0253]],
#
#                        [[-0.0347]],
#
#                        [[-0.1013]],
#
#                        [[ 0.0319]],
#
#                        [[-0.1886]],
#
#                        [[ 0.1468]],
#
#                        [[-0.0223]],
#
#                        [[ 0.0599]],
#
#                        [[ 0.0213]]],
#
#
#                       [[[-0.0810]],
#
#                        [[ 0.0552]],
#
#                        [[ 0.1376]],
#
#                        [[-0.0298]],
#
#                        [[-0.0119]],
#
#                        [[-0.0325]],
#
#                        [[-0.0765]],
#
#                        [[ 0.1775]],
#
#                        [[-0.0051]],
#
#                        [[-0.1308]],
#
#                        [[ 0.1167]],
#
#                        [[-0.0425]],
#
#                        [[ 0.1666]],
#
#                        [[ 0.0083]],
#
#                        [[-0.2000]],
#
#                        [[-0.1899]]],
#
#
#                       [[[-0.1274]],
#
#                        [[-0.2629]],
#
#                        [[ 0.2659]],
#
#                        [[-0.1665]],
#
#                        [[-0.1168]],
#
#                        [[ 0.1293]],
#
#                        [[-0.2083]],
#
#                        [[-0.1915]],
#
#                        [[-0.0493]],
#
#                        [[-0.0157]],
#
#                        [[-0.0946]],
#
#                        [[-0.1545]],
#
#                        [[-0.2315]],
#
#                        [[ 0.1470]],
#
#                        [[-0.0209]],
#
#                        [[-0.1775]]]])),
#              ('layers.0.bn1.weight',
#               tensor([0.9924, 0.9701, 0.9932, 1.0006, 0.9876, 0.9905, 0.9881, 1.0012, 0.9790,
#                       0.9993, 0.9859, 0.9928, 1.0131, 0.9945, 0.9887, 0.9902])),
#              ('layers.0.bn1.bias',
#               tensor([ 0.0110,  0.0396,  0.0089,  0.0041,  0.0129,  0.0125,  0.0124, -0.0033,
#                        0.0194, -0.0034,  0.0151,  0.0093,  0.0003,  0.0058,  0.0189,  0.0100])),
#              ('layers.0.bn1.running_mean',
#               tensor([-0.0281,  0.2315, -0.0653,  0.0920, -0.0839,  0.0244, -0.1507,  0.0253,
#                       -0.0145, -0.0258, -0.0910, -0.0158, -0.1211,  0.0890, -0.0227, -0.2093])),
#              ('layers.0.bn1.running_var',
#               tensor([0.0419, 0.0495, 0.1943, 0.0469, 0.0419, 0.0529, 0.0645, 0.0601, 0.0394,
#                       0.0230, 0.0416, 0.1556, 0.0381, 0.0669, 0.0179, 0.1775])),
#              ('layers.0.bn1.num_batches_tracked', tensor(4186)),
#              ('layers.0.conv2.weight',
#               tensor([[[[-0.0453,  0.1426, -0.0501],
#                         [ 0.2404, -0.1230,  0.0361],
#                         [ 0.3307, -0.0978, -0.2809]]],
#
#
#                       [[[ 0.3140,  0.3135, -0.2809],
#                         [ 0.2289, -0.1380, -0.2407],
#                         [-0.1868, -0.1956,  0.2215]]],
#
#
#                       [[[ 0.2497, -0.1645, -0.2495],
#                         [ 0.1348, -0.3057, -0.0017],
#                         [ 0.2811, -0.0704,  0.1121]]],
#
#
#                       [[[-0.0031, -0.1788, -0.0964],
#                         [-0.1489,  0.2212, -0.1941],
#                         [-0.2550, -0.0900,  0.2759]]],
#
#
#                       [[[-0.3413, -0.0569, -0.0583],
#                         [ 0.0336,  0.1743, -0.1439],
#                         [ 0.2294, -0.2801,  0.1883]]],
#
#
#                       [[[-0.1712,  0.1262,  0.2053],
#                         [-0.2029,  0.2770, -0.0713],
#                         [ 0.2148, -0.2969, -0.2225]]],
#
#
#                       [[[ 0.1691, -0.0406, -0.1273],
#                         [-0.2066,  0.1622,  0.1200],
#                         [-0.3135, -0.1333, -0.0014]]],
#
#
#                       [[[-0.2185,  0.2660, -0.2485],
#                         [ 0.1155, -0.1813,  0.0050],
#                         [-0.1681, -0.3017,  0.2469]]],
#
#
#                       [[[-0.2579, -0.1272, -0.1678],
#                         [ 0.1528,  0.0184, -0.0798],
#                         [-0.0931, -0.0042, -0.3175]]],
#
#
#                       [[[ 0.0086, -0.2285,  0.0021],
#                         [-0.0936, -0.1602, -0.0585],
#                         [ 0.0041,  0.0021,  0.0380]]],
#
#
#                       [[[-0.2383, -0.0925, -0.2414],
#                         [ 0.0260, -0.2411,  0.2195],
#                         [-0.0948, -0.1115, -0.2100]]],
#
#
#                       [[[ 0.2474,  0.2952,  0.1199],
#                         [ 0.0088, -0.0876, -0.2392],
#                         [-0.1770,  0.2646,  0.2163]]],
#
#
#                       [[[-0.1665,  0.2872, -0.2348],
#                         [-0.2817, -0.1104, -0.1311],
#                         [-0.2925, -0.1372, -0.1969]]],
#
#
#                       [[[ 0.1586,  0.2660,  0.0006],
#                         [ 0.2371,  0.0773, -0.0707],
#                         [-0.1111,  0.1134,  0.3082]]],
#
#
#                       [[[ 0.2392,  0.0272,  0.3248],
#                         [-0.0083,  0.1417,  0.1017],
#                         [ 0.2449,  0.0697,  0.1107]]],
#
#
#                       [[[-0.3206, -0.0736, -0.0195],
#                         [-0.0027, -0.1230,  0.0342],
#                         [-0.2047, -0.0719, -0.2308]]]])),
#              ('layers.0.bn2.weight',
#               tensor([1.0196, 0.9661, 1.0207, 1.0013, 0.9951, 1.0209, 0.9978, 0.9968, 1.0073,
#                       0.9832, 1.0071, 1.0097, 0.9878, 0.9875, 1.0065, 0.9880])),
#              ('layers.0.bn2.bias',
#               tensor([ 0.0417,  0.0190,  0.0144,  0.0007,  0.0134,  0.0164,  0.0040,  0.0253,
#                        0.0009, -0.0072,  0.0087,  0.0060, -0.0021,  0.0090,  0.0126, -0.0063])),
#              ('layers.0.bn2.running_mean',
#               tensor([ 0.0609,  0.0083, -0.0098, -0.1621, -0.1018, -0.0594, -0.1410, -0.1721,
#                       -0.3243, -0.1829, -0.3832,  0.2370, -0.5040,  0.4054,  0.4803, -0.4202])),
#              ('layers.0.bn2.running_var',
#               tensor([0.0405, 0.0521, 0.0437, 0.1323, 0.0381, 0.0347, 0.0267, 0.0550, 0.2619,
#                       0.0445, 0.1532, 0.0927, 0.3378, 0.3114, 0.3154, 0.1603])),
#              ('layers.0.bn2.num_batches_tracked', tensor(4186)),
#              ('layers.0.conv3.weight',
#               tensor([[[[-0.0690]],
#
#                        [[-0.0095]],
#
#                        [[-0.1113]],
#
#                        [[ 0.0532]],
#
#                        [[-0.1313]],
#
#                        [[ 0.0233]],
#
#                        [[-0.1738]],
#
#                        [[-0.0679]],
#
#                        [[ 0.0539]],
#
#                        [[-0.1245]],
#
#                        [[ 0.0251]],
#
#                        [[ 0.1552]],
#
#                        [[ 0.2015]],
#
#                        [[ 0.0649]],
#
#                        [[-0.2046]],
#
#                        [[-0.0309]]],
#
#
#                       [[[-0.2061]],
#
#                        [[ 0.1492]],
#
#                        [[ 0.2225]],
#
#                        [[ 0.0384]],
#
#                        [[-0.2394]],
#
#                        [[ 0.2192]],
#
#                        [[-0.1068]],
#
#                        [[ 0.2281]],
#
#                        [[ 0.0551]],
#
#                        [[ 0.1207]],
#
#                        [[-0.0896]],
#
#                        [[-0.1419]],
#
#                        [[-0.0343]],
#
#                        [[ 0.0811]],
#
#                        [[-0.1834]],
#
#                        [[-0.0504]]],
#
#
#                       [[[-0.1678]],
#
#                        [[-0.1297]],
#
#                        [[-0.1281]],
#
#                        [[-0.0823]],
#
#                        [[-0.1259]],
#
#                        [[ 0.2425]],
#
#                        [[ 0.0145]],
#
#                        [[-0.2184]],
#
#                        [[ 0.2410]],
#
#                        [[-0.2426]],
#
#                        [[-0.0964]],
#
#                        [[-0.2056]],
#
#                        [[ 0.1548]],
#
#                        [[ 0.2199]],
#
#                        [[-0.0158]],
#
#                        [[-0.2120]]],
#
#
#                       [[[-0.1131]],
#
#                        [[-0.2066]],
#
#                        [[-0.1194]],
#
#                        [[ 0.1839]],
#
#                        [[ 0.1216]],
#
#                        [[-0.0814]],
#
#                        [[-0.1591]],
#
#                        [[ 0.0502]],
#
#                        [[ 0.0253]],
#
#                        [[ 0.1116]],
#
#                        [[-0.1119]],
#
#                        [[ 0.1623]],
#
#                        [[-0.1177]],
#
#                        [[-0.0877]],
#
#                        [[-0.0305]],
#
#                        [[-0.0839]]],
#
#
#                       [[[-0.1635]],
#
#                        [[ 0.1419]],
#
#                        [[ 0.0660]],
#
#                        [[-0.1879]],
#
#                        [[ 0.0864]],
#
#                        [[ 0.1105]],
#
#                        [[ 0.2009]],
#
#                        [[ 0.0110]],
#
#                        [[-0.1527]],
#
#                        [[-0.0113]],
#
#                        [[ 0.0255]],
#
#                        [[ 0.1111]],
#
#                        [[-0.0219]],
#
#                        [[ 0.2028]],
#
#                        [[ 0.1316]],
#
#                        [[-0.2250]]],
#
#
#                       [[[ 0.2152]],
#
#                        [[-0.1614]],
#
#                        [[-0.0359]],
#
#                        [[-0.2131]],
#
#                        [[-0.0935]],
#
#                        [[ 0.0103]],
#
#                        [[ 0.1885]],
#
#                        [[-0.0405]],
#
#                        [[ 0.0327]],
#
#                        [[ 0.0799]],
#
#                        [[ 0.0285]],
#
#                        [[-0.1085]],
#
#                        [[-0.2195]],
#
#                        [[ 0.0595]],
#
#                        [[ 0.0193]],
#
#                        [[ 0.0815]]],
#
#
#                       [[[ 0.1882]],
#
#                        [[-0.2106]],
#
#                        [[-0.2055]],
#
#                        [[ 0.1238]],
#
#                        [[-0.0910]],
#
#                        [[-0.0201]],
#
#                        [[ 0.2551]],
#
#                        [[ 0.0841]],
#
#                        [[-0.0805]],
#
#                        [[-0.1671]],
#
#                        [[ 0.2546]],
#
#                        [[-0.0726]],
#
#                        [[ 0.1091]],
#
#                        [[-0.0859]],
#
#                        [[ 0.1108]],
#
#                        [[ 0.0505]]],
#
#
#                       [[[ 0.1889]],
#
#                        [[-0.1228]],
#
#                        [[ 0.1149]],
#
#                        [[-0.1148]],
#
#                        [[-0.1528]],
#
#                        [[ 0.1785]],
#
#                        [[-0.1747]],
#
#                        [[ 0.1866]],
#
#                        [[ 0.1432]],
#
#                        [[-0.2006]],
#
#                        [[-0.0522]],
#
#                        [[ 0.1434]],
#
#                        [[ 0.1859]],
#
#                        [[ 0.0718]],
#
#                        [[-0.0031]],
#
#                        [[ 0.0315]]],
#
#
#                       [[[ 0.0524]],
#
#                        [[ 0.1153]],
#
#                        [[-0.0767]],
#
#                        [[-0.1812]],
#
#                        [[-0.1300]],
#
#                        [[-0.1858]],
#
#                        [[-0.1305]],
#
#                        [[-0.0003]],
#
#                        [[-0.0177]],
#
#                        [[-0.0467]],
#
#                        [[ 0.0299]],
#
#                        [[ 0.1119]],
#
#                        [[ 0.1981]],
#
#                        [[-0.1868]],
#
#                        [[-0.2075]],
#
#                        [[-0.1733]]],
#
#
#                       [[[ 0.1884]],
#
#                        [[-0.0564]],
#
#                        [[-0.0252]],
#
#                        [[ 0.1466]],
#
#                        [[-0.1937]],
#
#                        [[ 0.2171]],
#
#                        [[-0.1277]],
#
#                        [[ 0.1981]],
#
#                        [[ 0.0404]],
#
#                        [[-0.0496]],
#
#                        [[ 0.2475]],
#
#                        [[-0.1130]],
#
#                        [[ 0.0388]],
#
#                        [[ 0.1891]],
#
#                        [[ 0.1060]],
#
#                        [[-0.0322]]],
#
#
#                       [[[-0.1439]],
#
#                        [[-0.0889]],
#
#                        [[ 0.1001]],
#
#                        [[ 0.1712]],
#
#                        [[ 0.1816]],
#
#                        [[-0.0881]],
#
#                        [[ 0.2142]],
#
#                        [[-0.0062]],
#
#                        [[ 0.2602]],
#
#                        [[ 0.0116]],
#
#                        [[-0.0814]],
#
#                        [[ 0.1287]],
#
#                        [[ 0.0107]],
#
#                        [[-0.2181]],
#
#                        [[ 0.0592]],
#
#                        [[ 0.1275]]],
#
#
#                       [[[-0.0024]],
#
#                        [[-0.1246]],
#
#                        [[-0.0312]],
#
#                        [[-0.1926]],
#
#                        [[ 0.0456]],
#
#                        [[ 0.1772]],
#
#                        [[ 0.1776]],
#
#                        [[ 0.0242]],
#
#                        [[ 0.2376]],
#
#                        [[ 0.0950]],
#
#                        [[-0.0869]],
#
#                        [[ 0.1645]],
#
#                        [[-0.1380]],
#
#                        [[ 0.1409]],
#
#                        [[ 0.2226]],
#
#                        [[ 0.2305]]],
#
#
#                       [[[-0.1739]],
#
#                        [[ 0.0206]],
#
#                        [[-0.1065]],
#
#                        [[ 0.2036]],
#
#                        [[ 0.1806]],
#
#                        [[ 0.1553]],
#
#                        [[-0.0501]],
#
#                        [[-0.2336]],
#
#                        [[-0.2383]],
#
#                        [[-0.0534]],
#
#                        [[ 0.0793]],
#
#                        [[ 0.1314]],
#
#                        [[-0.2252]],
#
#                        [[ 0.0871]],
#
#                        [[-0.1289]],
#
#                        [[ 0.0538]]],
#
#
#                       [[[-0.0794]],
#
#                        [[-0.1957]],
#
#                        [[-0.2539]],
#
#                        [[-0.1061]],
#
#                        [[ 0.0371]],
#
#                        [[-0.0010]],
#
#                        [[-0.0592]],
#
#                        [[ 0.1120]],
#
#                        [[-0.2028]],
#
#                        [[ 0.2282]],
#
#                        [[-0.1484]],
#
#                        [[ 0.0460]],
#
#                        [[ 0.1833]],
#
#                        [[ 0.1128]],
#
#                        [[-0.1603]],
#
#                        [[ 0.1838]]],
#
#
#                       [[[-0.0399]],
#
#                        [[ 0.2293]],
#
#                        [[ 0.1860]],
#
#                        [[-0.1675]],
#
#                        [[-0.0325]],
#
#                        [[-0.1318]],
#
#                        [[-0.0600]],
#
#                        [[-0.2368]],
#
#                        [[-0.0595]],
#
#                        [[ 0.1959]],
#
#                        [[ 0.2411]],
#
#                        [[ 0.2338]],
#
#                        [[ 0.0475]],
#
#                        [[ 0.2589]],
#
#                        [[ 0.1105]],
#
#                        [[ 0.1329]]],
#
#
#                       [[[ 0.2480]],
#
#                        [[-0.1732]],
#
#                        [[ 0.1972]],
#
#                        [[ 0.1133]],
#
#                        [[ 0.0512]],
#
#                        [[ 0.0975]],
#
#                        [[ 0.0786]],
#
#                        [[ 0.1568]],
#
#                        [[ 0.0748]],
#
#                        [[ 0.1423]],
#
#                        [[-0.0147]],
#
#                        [[-0.0431]],
#
#                        [[-0.1866]],
#
#                        [[ 0.1549]],
#
#                        [[-0.1378]],
#
#                        [[ 0.0172]]]])),
#              ('layers.0.bn3.weight',
#               tensor([0.9996, 1.0108, 0.9901, 1.0160, 0.9948, 0.9912, 0.9883, 0.9897, 0.9955,
#                       0.9943, 0.9993, 1.0037, 1.0078, 1.0063, 0.9969, 1.0140])),
#              ('layers.0.bn3.bias',
#               tensor([-0.0134, -0.0051, -0.0042, -0.0015,  0.0005,  0.0009, -0.0021, -0.0016,
#                        0.0028,  0.0012,  0.0024,  0.0020, -0.0022,  0.0004,  0.0043,  0.0112])),
#              ('layers.0.bn3.running_mean',
#               tensor([-0.0588, -0.0187, -0.1380, -0.0768,  0.0652, -0.0183,  0.0797,  0.0792,
#                       -0.1614,  0.1498,  0.1258,  0.2014, -0.0526, -0.0243,  0.1759,  0.1363])),
#              ('layers.0.bn3.running_var',
#               tensor([0.0357, 0.0278, 0.0272, 0.0219, 0.0178, 0.0195, 0.0198, 0.0212, 0.0152,
#                       0.0147, 0.0139, 0.0251, 0.0347, 0.0370, 0.0647, 0.0226])),
#              ('layers.0.bn3.num_batches_tracked', tensor(4186)),
#              ('layers.1.conv1.weight',
#               tensor([[[[ 0.2141]],
#
#                        [[-0.1452]],
#
#                        [[ 0.1700]],
#
#                        ...,
#
#                        [[ 0.1620]],
#
#                        [[-0.1088]],
#
#                        [[-0.0970]]],
#
#
#                       [[[-0.1501]],
#
#                        [[-0.2396]],
#
#                        [[-0.1802]],
#
#                        ...,
#
#                        [[ 0.2149]],
#
#                        [[-0.2001]],
#
#                        [[ 0.2462]]],
#
#
#                       [[[-0.1311]],
#
#                        [[-0.1752]],
#
#                        [[-0.1369]],
#
#                        ...,
#
#                        [[ 0.1025]],
#
#                        [[ 0.1027]],
#
#                        [[ 0.0946]]],
#
#
#                       ...,
#
#
#                       [[[ 0.0846]],
#
#                        [[ 0.2219]],
#
#                        [[-0.2310]],
#
#                        ...,
#
#                        [[-0.0013]],
#
#                        [[-0.2086]],
#
#                        [[ 0.1513]]],
#
#
#                       [[[-0.0406]],
#
#                        [[ 0.1985]],
#
#                        [[ 0.1953]],
#
#                        ...,
#
#                        [[ 0.1290]],
#
#                        [[-0.1148]],
#
#                        [[ 0.1700]]],
#
#
#                       [[[ 0.0160]],
#
#                        [[ 0.1087]],
#
#                        [[ 0.0903]],
#
#                        ...,
#
#                        [[ 0.0475]],
#
#                        [[ 0.0132]],
#
#                        [[ 0.0646]]]])),
#              ('layers.1.bn1.weight',
# ...
#                       -9.1312e-04, -1.9172e-04, -6.0729e-04, -6.4340e-05,  3.6594e-04,
#                        1.0763e-05, -2.9327e-04, -6.3619e-04,  4.9268e-04,  4.4609e-05,
#                        1.4902e-04,  3.6046e-04,  1.1752e-04,  6.6751e-04, -7.1898e-05,
#                       -2.3104e-04, -9.0332e-05, -1.8847e-04,  3.9106e-05,  1.0989e-04,
#                        1.5106e-04, -2.4992e-04, -8.7959e-05, -4.2845e-04, -1.3284e-05,
#                        3.2080e-04,  5.3776e-04,  7.2549e-04,  5.8400e-04, -3.6117e-05,
#                       -9.1758e-04, -4.5309e-04, -2.5471e-04,  1.9953e-04, -2.3689e-04,
#                       -5.0764e-04,  9.4602e-06, -1.8638e-05, -2.4062e-06, -5.7304e-04,
#                       -4.0153e-04, -7.5489e-04,  8.1496e-04,  1.4942e-04, -3.7518e-05,
#                       -2.5234e-04, -7.4346e-04,  6.3329e-05, -2.9500e-04, -5.5335e-04,
#                       -7.3136e-04, -1.3930e-04,  6.5835e-06, -3.1243e-04, -2.2173e-04,
#                        4.1200e-05, -3.4227e-04,  3.5740e-04, -6.5975e-04, -5.3206e-04,
]],
#
#
#                       ...,
#
#
#                       [[[ 0.0265]],
#
#                        [[-0.0531]],
#
#                        [[ 0.0921]],
#
#                        ...,
#
#                        [[ 0.0118]],
#
#                        [[ 0.0122]],
#
#                        [[ 0.0165]]],
#
#
#                       [[[-0.0067]],
#
#                        [[-0.0233]],
#
#                        [[-0.0169]],
#
#                        ...,
#
#                        [[ 0.0304]],
#
#                        [[ 0.0120]],
#
#                        [[-0.0446]]],
#
#
#                       [[[-0.0364]],
#
#                        [[ 0.0029]],
#
#                        [[ 0.0235]],
#
#                        ...,
#
#                        [[ 0.0497]],
#
#                        [[-0.0469]],
#
#                        [[-0.0368]]]])),
#              ('conv3.bias',
#               tensor([-0.0059,  0.0197, -0.0043,  ...,  0.0029,  0.0319, -0.0234])),
#              ('conv4.weight',
#               tensor([[[[ 0.0291]],
#
#                        [[-0.0424]],
#
#                        [[ 0.0174]],
#
#                        ...,
#
#                        [[-0.0411]],
#
#                        [[ 0.0149]],
#
#                        [[-0.0087]]],
#
#
#                       [[[-0.0337]],
#
#                        [[ 0.0147]],
#
#                        [[-0.0478]],
#
#                        ...,
#
#                        [[-0.0225]],
#
#                        [[-0.0108]],
#
#                        [[-0.0408]]],
#
#
#                       [[[-0.0215]],
#
#                        [[ 0.0327]],
#
#                        [[-0.0290]],
#
#                        ...,
#
#                        [[-0.0313]],
#
#                        [[-0.0426]],
#
#                        [[ 0.0019]]],
#
#
#                       ...,
#
#
#                       [[[-0.0104]],
#
#                        [[ 0.0024]],
#
#                        [[ 0.0030]],
#
#                        ...,
#
#                        [[-0.0143]],
#
#                        [[-0.0228]],
#
#                        [[-0.0375]]],
#
#
#                       [[[ 0.0164]],
#
#                        [[-0.0156]],
#
#                        [[-0.0082]],
#
#                        ...,
#
#                        [[-0.0339]],
#
#                        [[-0.0496]],
#
#                        [[ 0.0099]]],
#
#
#                       [[[-0.0364]],
#
#                        [[-0.0295]],
#
#                        [[ 0.0243]],
#
#                        ...,
#
#                        [[-0.0273]],
#
#                        [[-0.0082]],
#
#                        [[-0.0113]]]])),
#              ('conv4.bias',
#               tensor([-0.0070, -0.0024,  0.0025, -0.0126, -0.0277, -0.0076, -0.0386,  0.0430,
#                       -0.0170, -0.0017,  0.0143,  0.0077, -0.0051, -0.0057, -0.0394, -0.0141,
#                        0.0267]))])

# %%
def _make_divisible(v, divisor, min_value=None):
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    :param v:
    :param divisor:
    :param min_value:
    :return:
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v

# %%
_make_divisible(32*0.4, 4)
# Out:
# 12
